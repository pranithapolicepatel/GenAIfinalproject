# %% [markdown]
# <a href="https://colab.research.google.com/github/pranithapolicepatel/GenAIfinalproject/blob/main/GenAIFinalProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Welcome to Colab!</h1>
# </div>
#
# <div class="markdown-google-sans">
#   <h2>Explore the Gemini API</h2>
#   <p>The Gemini API gives you access to Gemini models created by Google DeepMind. Gemini models are built from the ground up to be multimodal, so you can reason seamlessly across text, images, code, and audio.
#   </p>
#   <strong>How to get started</strong>
#     <ol>
#       <li>Go to <a href="https://aistudio.google.com/">Google AI Studio</a> and log in with your Google account.</li>
#       <li><a href="https://aistudio.google.com/app/apikey">Create an API key</a>.</li>
#       <li>Use a quickstart for <a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Prompting.ipynb">Python</a>, or call the REST API using <a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/rest/Prompting_REST.ipynb">curl</a>.</li>
#       </ol>
#   <strong>Explore use cases</strong>
#     <ul>
#       <li><a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Market_a_Jet_Backpack.ipynb">Create a marketing campaign</a></li>
#       <li><a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Audio.ipynb">Analyze audio recordings</a></li>
#       <li><a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/System_instructions.ipynb">Use System instructions in chat</a></li>
#     </ul>
#   <p>To learn more, check out the <a href="https://github.com/google-gemini/cookbook">Gemini cookbook</a> or visit the <a href="https://ai.google.dev/docs/">Gemini API documentation</a>.
#   </p>
# </div>

# %% [markdown]
# If you're already familiar with Colab, check out this video to learn about interactive tables, the executed code history view, and the command palette.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Thumbnail for a video showing 3 cool Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) to learn more, or just get started below!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **Getting started**
# </div>
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To learn more about the Jupyter project, see [jupyter.org](https://www.jupyter.org).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data science
# </div>
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from Github and many other sources. To learn more about importing data, and how Colab can be used for data science, see the links below under [Working with Data](#working-with-data).

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %% [markdown]
# Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.
#
# For example, if you find yourself waiting for **pandas** code to finish running and want to go faster, you can switch to a GPU Runtime and use libraries like [RAPIDS cuDF](https://rapids.ai/cudf-pandas) that provide zero-code-change acceleration.

# %% [markdown]
# To learn more about accelerating pandas on Colab, see the [10 minute guide](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_colab_demo.ipynb) or
#  [US stock market data analysis demo](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_stocks_demo.ipynb).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb).

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## More Resources
#
# ### Working with Notebooks in Colab
#
# </div>
#
# - [Overview of Colab](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Working with Data
# </div>
#
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine Learning Crash Course
#
# <div>
#
# These are a few of the notebooks from Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Intro to RAPIDS cuDF to accelerate pandas](https://nvda.ws/rapids-cudf)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# </div>
#
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow with TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# </div>
#
# - [Retraining an Image Classifier](https://tensorflow.org/hub/tutorials/tf2_image_retraining): Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - [Text Classification](https://tensorflow.org/hub/tutorials/tf2_text_classification): Classify IMDB movie reviews as either *positive* or *negative*.
# - [Style Transfer](https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization): Use deep learning to transfer style between images.
# - [Multilingual Universal Sentence Encoder Q&A](https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa): Use a machine learning model to answer questions from the SQuAD dataset.
# - [Video Interpolation](https://tensorflow.org/hub/tutorials/tweening_conv3d): Predict what happened in a video between the first and the last frame.

# %%
import os
from os import walk
import re
import csv
import pandas as pd
from bs4 import BeautifulSoup
import spacy

# %%
folder_path = "/content/"
df = None

# Iterate through the contents of the folder
for filename in os.listdir(folder_path):
    # Join the folder path with the filename to get the full path
    full_path = os.path.join(folder_path, filename)

    # Check if the current item is a file or a directory
    if os.path.isfile(full_path):
      print(full_path)
      temp_df = pd.read_csv(full_path, skipinitialspace=True)
      if df is None:
        df = temp_df
      else:
        df = pd.concat([df, temp_df])
# Out:
# /content/qrvK_KuIeJk.csv
# /content/880TBXMuzmk.csv
# /content/WY518YRfs5M.csv
# /content/XKMvk5hWDfo.csv
# /content/C_78DM8fG6E.csv
# /content/rb7NddXDdxs.csv
# /content/vJefOB8kec8.csv
# /content/eXdVDhOGqoE.csv
# /content/_x9AwxfjxvE.csv
# /content/aZ5EsdnpLMI.csv
# /content/LWiM-LuRe6w.csv
# /content/540vzMlf-54.csv
# /content/RdAQnkDzGvc.csv
# /content/VzUmLAUPSQo.csv
# /content/b76gsOSkHB4.csv
# /content/uJnhh7YSr5Q.csv
# /content/SVcsDDABEkM.csv
# /content/cqc0xni25n0.csv
# /content/xoVJKj8lcNQ.csv
# /content/Yd0yQ9yxSYY.csv
# /content/gMsQO5u7-NQ.csv
# /content/-qReeg7imGc.csv
# /content/Tpq3hRt0pmw.csv
# /content/USsh-XK6s6U.csv
# /content/hJP5GqnTrNo.csv
# /content/2yd18z6iSyk.csv

# %%
nan_indices = df['Comment'].isna()

# Replace NaN values with empty strings
df['Comment'] = df['Comment'].fillna('')

# %%
def clean_text(text):
    # Remove HTML tags
    soup = BeautifulSoup(text, 'html.parser')
    text = soup.get_text()

    # Remove special ASCII symbols
    text = re.sub(r'[^\x00-\x7F]+', '', text)

    # Remove asterisks around each letter in the phrase and words attached to @
    text = re.sub(r'\*|@\w+|@|\?|!', '', text)

    return text.strip()

# %%
# Apply clean_text function only to non-null values
df['clean_comment'] = df['Comment'].apply(lambda x: clean_text(x) if not pd.isnull(x) else x)
# Out:
# <ipython-input-4-f0f29cc38ca6>:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, 'html.parser')

# %%
def filter_sentences(text):
    sentences = text.split('.')
    filtered_sentences = [sentence for sentence in sentences if len(sentence.split()) >= 5]
    return '. '.join(filtered_sentences)


# Apply the function to the 'clean_comment' column
df['clean_comment'] = df['clean_comment'].apply(filter_sentences)

# %%
# Function to filter out rows with empty 'clean_comment' values
def filter_empty_comments(row):
    return row['clean_comment'] != '' or row['clean_comment'] != None

# Apply the function to filter out rows with empty 'clean_comment' values
df = df[df.apply(filter_empty_comments, axis=1)]

# %%
import spacy
spacy.load('en_core_web_sm')
from spacy.lang.en import English
parser = English()
def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            lda_tokens.append('SCREEN_NAME')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens

# %%
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet as wn
def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma

from nltk.stem.wordnet import WordNetLemmatizer
def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
nltk.download('stopwords')
en_stop = set(nltk.corpus.stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def prepare_text_for_lda(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 4]
    tokens = [token for token in tokens if token not in en_stop]
    tokens = [get_lemma(token) for token in tokens]
    return tokens

# %%
df["tokens"] = df["clean_comment"].apply(prepare_text_for_lda)

# %%
def get_topic_dict(text):
    dict_ = {}
    text = text.split("+")
    for i in range(len(text)):
        text[i] = text[i].strip()
        temp = text[i].split("*")
        if len(temp) >= 2 and temp[0] != "":
            dict_[temp[1][1:-1]] = float(re.search(r'\d+', temp[0]).group())

    return dict_

# %%
import gensim
from gensim import corpora
def get_topics(tokens):
    if len(tokens) != 0:
        dictionary = corpora.Dictionary([tokens])
        corpus = [dictionary.doc2bow(tokens)]
        NUM_TOPICS = 1
        ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
        ldamodel.save('model5.gensim')
        topics = ldamodel.print_topics(num_words=len(tokens))
        return get_topic_dict(topics[0][1])
    else:
        return {}

# %%
df['topics'] = df["tokens"].apply(get_topics)

# %%
df = df[df['topics'] != {}]

# %%
for i in df['topics']:
    print(i)
# Out:
# Streaming output truncated to the last 5000 lines.
# {'topic': 1.0}
# {'condom': 0.0, 'dhruv': 0.0, 'example': 0.0, 'perfect': 0.0, 'rathee': 0.0}
# {'video': 1.0}
# {'avtar': 0.0, 'bhagwan': 0.0, 'coming': 0.0, 'kalki': 0.0, 'kalyug': 0.0, 'vishnu': 0.0}
# {'bache': 0.0, 'course': 0.0, 'gareebo': 0.0, 'interest': 0.0, 'kaise': 0.0, 'krenge': 0.0, 'mehnga': 0.0, 'purchase': 0.0}
# {'topic': 0.0, 'video': 0.0}
# {'banao': 0.0, 'chijo': 0.0, 'prachin': 0.0, 'video': 0.0}
# {'artificial': 0.0, 'intelligence': 0.0, 'jamia': 0.0, 'power': 0.0, 'student': 0.0, 'telling': 0.0}
# {'banate': 0.0, 'research': 0.0, 'video': 0.0}
# {'could': 0.0, 'creative': 0.0, 'enlighten': 0.0, 'happy': 0.0, 'impact': 0.0, 'please': 0.0, 'replace': 0.0, 'student': 0.0, 'years': 0.0}
# {'topic': 1.0}
# {'chatgpt': 0.0, 'video': 0.0}
# {'interest': 0.0, 'video': 0.0}
# {'development': 0.0, 'harmful': 0.0, 'slow': 0.0, 'technology': 0.0, 'useful': 0.0, 'user': 0.0}
# {'going': 1.0}
# {'dhruv': 1.0}
# {'aapse': 0.0, 'bohot': 0.0, 'level': 0.0, 'neeche': 0.0}
# {'manipur': 0.0, 'video': 0.0, 'violence': 0.0}
# {'video': 1.0}
# {'video': 0.0, 'aware': 0.0, 'brother': 0.0, 'dhruv': 0.0, 'incident': 0.0, 'indian': 0.0, 'make': 0.0, 'manipur': 0.0, 'naked': 0.0, 'rush': 0.0, 'seeing': 0.0, 'viedo': 0.0, 'woman': 0.0}
# {'manipur': 0.0, 'video': 0.0}
# {'might': 0.0, 'takeover': 0.0, 'world': 0.0}
# {'haider': 0.0, 'hoplease': 0.0, 'sakte': 0.0, 'seema': 0.0, 'sovle': 0.0, 'study': 0.0, 'topic': 0.0, 'video': 0.0}
# {'dhruv': 0.0, 'intelligent': 0.0, 'super': 0.0}
# {'please': 0.0, 'complete': 0.0, 'detail': 0.0, 'notion': 0.0, 'saath': 0.0, 'treeke': 0.0, 'vedio': 0.0}
# {'going': 0.0, 'really': 0.0}
# {'aapke': 0.0, 'editing': 0.0, 'kaise': 0.0, 'sakta': 0.0, 'seekh': 0.0, 'tarah': 0.0}
# {'change': 0.0, 'course': 0.0, 'french': 0.0, 'mention': 0.0, 'speak': 0.0, 'video': 0.0}
# {'person': 0.0, 'using': 0.0}
# {'creation': 0.0, 'world': 0.0}
# {'party': 0.0, 'video': 0.0, 'banayega': 0.0, 'banda': 0.0, 'delhi': 0.0, 'kyuki': 0.0, 'ruler': 0.0, 'topic': 0.0}
# {'entry': 1.0}
# {'manipur': 0.0, 'video': 0.0}
# {'bengal': 0.0, 'election': 0.0, 'panchayat': 0.0, 'video': 0.0}
# {'ayega': 0.0, 'business': 0.0, 'change': 0.0, 'google': 0.0, 'hmesa': 0.0, 'kyuki': 0.0, 'purana': 0.0, 'purani': 0.0, 'zuckerberg': 0.0}
# {'please': 0.0, 'video': 0.0}
# {'bigboss': 0.0, 'lalantop': 0.0}
# {'please': 0.0, 'topic': 0.0, 'video': 0.0}
# {'video': 1.0}
# {'deshdrohi': 0.0, 'insaan': 0.0, 'katva': 0.0}
# {'deshdrohi': 0.0, 'insaan': 0.0, 'katva': 0.0}
# {'deshdrohi': 0.0, 'insaan': 0.0, 'katva': 0.0}
# {'price': 0.0, 'afford': 0.0, 'consider': 0.0, 'course': 0.0, 'informative': 0.0, 'others': 0.0, 'student': 0.0, 'thanks': 0.0}
# {'video': 1.0}
# {'learn': 0.0, 'dhruv': 0.0, 'rathee': 0.0, 'school': 0.0}
# {'deshbhakt': 0.0, 'dhruv': 0.0, 'like': 0.0, 'raathe': 0.0, 'video': 0.0, 'watch': 0.0, 'would': 0.0}
# {'please': 0.0, 'topic': 0.0}
# {'reality': 0.0, 'support': 0.0, 'thanks': 0.0}
# {'hormons': 1.0}
# {'big': 0.0, 'weapon': 0.0}
# {'bigboss': 0.0, 'never': 0.0}
# {'useful': 1.0}
# {'balance': 0.0, 'benefit': 0.0, 'emotional': 0.0, 'health': 0.0, 'meditation': 0.0, 'overall': 0.0, 'peace': 0.0, 'relax': 0.0, 'sense': 0.0, 'stress': 0.0}
# {'beautiful': 0.0, 'look': 0.0, 'thinking': 0.0, 'whole': 0.0, 'world': 0.0}
# {'going': 0.0, 'house': 0.0}
# {'video': 0.0, 'website': 0.0}
# {'aafia': 0.0, 'please': 0.0, 'siddiqi': 0.0, 'vedio': 0.0}
# {'point': 0.0, 'robot': 0.0, 'scare': 0.0, 'software': 0.0, 'still': 0.0}
# {'famous': 0.0, 'future': 0.0, 'image': 0.0}
# {'banaye': 0.0, 'chandeayan': 0.0, 'video': 0.0}
# {'base': 0.0, 'video': 0.0}
# {'video': 1.0}
# {'child': 0.0, 'course': 0.0, 'expensive': 0.0, 'quite': 0.0}
# {'chahiye': 0.0, 'social': 0.0, 'humare': 0.0, 'action': 0.0, 'track': 0.0, 'samajhkar': 0.0, 'sakte': 0.0, 'network': 0.0, 'medium': 0.0, 'manipulate': 0.0, 'like': 0.0, 'karna': 0.0, 'karke': 0.0, 'interact': 0.0, 'hisaab': 0.0, 'dislike': 0.0, 'cheez': 0.0, 'usske': 0.0, 'website': 0.0}
# {'command': 0.0, 'threat': 0.0, 'think': 0.0, 'serious': 0.0, 'robot': 0.0, 'remembering': 0.0, 'outperform': 0.0, 'mankind': 0.0, 'intelligence': 0.0, 'human': 0.0, 'future': 0.0, 'execute': 0.0, 'easily': 0.0, 'definitely': 0.0, 'dangerous': 0.0, 'create': 0.0, 'voice': 0.0, 'would': 0.0}
# {'video': 1.0}
# {'christ': 0.0, 'coming': 0.0, 'jesus': 0.0, 'peace': 0.0}
# {'people': 0.0, 'disease': 0.0, 'mentally': 0.0, 'physically': 0.0, 'suffer': 0.0, 'unhelthier': 0.0}
# {'bhakton': 0.0, 'gain': 0.0, 'lootne': 0.0, 'prince': 0.0, 'sanghi': 0.0}
# {'banav': 0.0, 'punarjanama': 0.0, 'video': 0.0}
# {'dengerous': 0.0, 'dhruv': 0.0, 'rathi': 0.0, 'worry': 0.0}
# {'hussein': 0.0, 'saddam': 0.0, 'storyline': 0.0}
# {'details': 1.0}
# {'hussein': 0.0, 'please': 0.0, 'saddam': 0.0, 'story': 0.0, 'video': 0.0}
# {'chandrayan': 0.0, 'detail': 0.0, 'please': 0.0, 'video': 0.0}
# {'video': 1.0}
# {'would': 1.0}
# {'entry': 0.0, 'karenge': 0.0}
# {'churte': 0.0, 'paisa': 0.0, 'kamate': 0.0, 'note': 0.0, 'point': 0.0, 'scammer': 0.0}
# {'future': 0.0, 'robot': 0.0, 'serving': 0.0}
# {'please': 0.0, 'video': 0.0}
# {'future': 1.0}
# {'video': 1.0}
# {'banayenge': 0.0, 'relate': 0.0, 'video': 0.0}
# {'banao': 0.0, 'vedio': 0.0}
# {'darkweb': 0.0, 'please': 0.0}
# {'every': 0.0, 'helping': 0.0, 'human': 0.0, 'imagine': 0.0, 'purpose': 0.0, 'single': 0.0, 'world': 0.0, 'would': 0.0}
# {'aanurotha': 0.0, 'aayegi': 0.0, 'biharmay': 0.0, 'chalaye': 0.0, 'class': 0.0, 'kumar': 0.0, 'mujhe': 0.0, 'phemaliyeplease': 0.0, 'please': 0.0, 'prince': 0.0, 'rikwest': 0.0, 'ripley': 0.0, 'shabhi': 0.0, 'shakhchham': 0.0, 'student': 0.0}
# {'choice': 0.0, 'return': 0.0, 'print("result': 0.0, 'number': 0.0, 'calculator': 0.0, 'operation': 0.0, 'float(input("enter': 0.0, 'add(x': 0.0, 'subtract(x': 0.0, 'square_root(x': 0.0, 'exponentiate(x': 0.0, 'multiply(x': 0.0, 'divide(x': 0.0, 'error': 0.0, 'first': 0.0, 'break': 0.0, 'calculate': 0.0, 'square': 0.0, 'sqrt(x': 0.0, 'second': 0.0, 'right': 0.0, 'choose': 0.0, 'continue': 0.0, 'print("invalid': 0.0, 'print("calculator': 0.0, 'print("1': 0.0, 'please': 0.0, 'divide': 0.0, 'negative': 0.0, 'valid': 0.0, 'input("enter': 0.0, 'input': 0.0, 'import': 0.0, 'enter': 0.0, 'print("exiting': 0.0, 'wrong': 0.0}
# {'please': 0.0, 'video': 0.0}
# {'hrithik': 0.0, 'video': 0.0}
# {'require': 0.0, 'video': 0.0}
# {'video': 1.0}
# {'defense': 1.0}
# {'account': 0.0, 'fantastic': 0.0, 'pakistan': 0.0, 'party': 0.0, 'political': 0.0, 'politics': 0.0, 'twitter': 0.0, 'video': 0.0}
# {'video': 0.0, 'waiting': 0.0}
# {'chandrayan': 0.0, 'video': 0.0}
# {'bangladesh': 0.0, 'course': 0.0, 'purchase': 0.0}
# {'abhinash': 0.0, 'karni': 0.0, 'youtuber': 0.0}
# {'topic': 0.0, 'want': 0.0}
# {'dhruve': 0.0, 'video': 0.0}
# {'learning': 0.0, 'machine': 0.0, 'science': 0.0, 'video': 0.0}
# {'please': 0.0, 'regard': 0.0, 'vedio': 0.0}
# {'sakte': 0.0, 'video': 0.0, 'course': 0.0, 'dhruv': 0.0, 'kharidne': 0.0}
# {'dhruv': 1.0}
# {'topic': 0.0, 'video': 0.0}
# {'khatm': 0.0, 'chahte': 0.0, 'cheezo': 0.0, 'insaniyat': 0.0, 'matlab': 0.0, 'rakhna': 0.0, 'randapa': 0.0}
# {'khatam': 1.0}
# {'chalna': 0.0, 'future': 0.0, 'impossible': 0.0, 'saath': 0.0}
# {'bigboss': 1.0}
# {'branch': 0.0, 'mujhe': 0.0, 'video': 0.0, 'engineering': 0.0, 'reply': 0.0, 'konsi': 0.0, 'kronga': 0.0, 'lekar': 0.0, 'lekin': 0.0, 'passout': 0.0, 'rahega': 0.0, 'reason': 0.0, 'science': 0.0, 'student': 0.0, 'thanks': 0.0, 'karan': 0.0, 'issue': 0.0, 'artificial': 0.0, 'trust': 0.0, 'hello': 0.0, 'graduation': 0.0, 'future': 0.0, 'dhurv': 0.0, 'dekhne': 0.0, 'confusion': 0.0, 'computer': 0.0, 'complete': 0.0, 'college': 0.0, 'choose': 0.0, 'chahta': 0.0, 'chahiye': 0.0, 'bahut': 0.0, 'intelligence': 0.0, 'information': 0.0}
# {'great': 0.0, 'informative': 0.0, 'usual': 0.0, 'video': 0.0}
# {'aapko': 0.0, 'bahut': 0.0, 'chahiye': 0.0, 'chatgpt': 0.0, 'cheap': 0.0, 'course': 0.0, 'dhruv': 0.0, 'price': 0.0, 'sakta': 0.0}
# {'note-': 1.0}
# {'another': 0.0, 'topic': 0.0, 'video': 0.0}
# {'literal': 0.0, 'thing': 0.0}
# {'channel': 0.0, 'credible': 0.0, 'general': 0.0, 'knowledge': 0.0, 'youtube': 0.0}
# {'please': 0.0, 'topic': 0.0, 'video': 0.0}
# {'video': 1.0}
# {'demak': 0.0, 'later': 0.0, 'ready': 0.0}
# {'video': 1.0}
# {'proud': 1.0}
# {'dhruv': 0.0, 'comment': 0.0, 'erroneously': 0.0, 'mean': 0.0, 'phenomenal': 0.0, 'point': 0.0, 'post': 0.0, 'really': 0.0, 'thank': 0.0, 'though': 0.0}
# {'dhruv': 1.0}
# {'start': 0.0, 'india': 0.0, 'language': 0.0, 'bengali': 0.0, 'telugu': 0.0, 'tamil': 0.0, 'suggestion': 0.0, 'specifically': 0.0, 'skip': 0.0, 'marathi': 0.0, 'making': 0.0, 'kannada': 0.0, 'hindi': 0.0, 'different': 0.0, 'dhruv': 0.0, 'could': 0.0, 'channels': 0.0, 'video': 0.0, 'would': 0.0}
# {'chandrayan': 0.0, 'please': 0.0, 'video': 0.0}
# {'manipur': 0.0, 'video': 0.0, 'violence': 0.0}
# {'biggboss': 0.0, 'entering': 0.0, 'rumour': 0.0}
# {'video': 1.0}
# {'hanuman': 0.0, 'disrespect': 0.0, 'hindu': 0.0, 'ok",but': 0.0, 'religion': 0.0, 'respect': 0.0, 'saying': 0.0, 'someone': 0.0, 'wanaa': 0.0, 'words': 0.0}
# {'baalo': 0.0, 'badiya': 0.0, 'dhruv': 0.0, 'lambe': 0.0}
# {'engineering': 0.0, 'episode': 0.0, 'mechanical': 0.0}
# {'please': 0.0, 'reveal': 0.0, 'simpson': 0.0}
# {'afford': 0.0, 'course': 0.0, 'expensive': 0.0}
# {'video': 1.0}
# {'cross': 0.0, 'threads': 0.0, 'user': 0.0}
# {'banao': 0.0, 'video': 0.0}
# {'learning': 0.0, 'machine': 0.0, 'science': 0.0, 'video': 0.0}
# {'please': 0.0, 'video': 0.0}
# {'base': 0.0, 'become': 0.0, 'control': 0.0, 'humans': 0.0, 'killing': 0.0, 'robot': 0.0, 'start': 0.0}
# {'topic': 0.0, 'country': 0.0, 'difficulty': 0.0, 'every': 0.0, 'relationship': 0.0, 'request': 0.0, 'understand': 0.0, 'video': 0.0}
# {'bigboss': 0.0, 'sachme': 0.0}
# {'dhurv': 1.0}
# {'aware': 0.0, 'people': 0.0, 'right': 0.0, 'video': 0.0}
# {'coming': 0.0, 'dhruv': 0.0, 'really': 0.0}
# {'deepfakeeeee': 0.0, 'detail': 0.0, 'video': 0.0}
# {'video': 1.0}
# {'english': 0.0, 'language': 0.0, 'learn': 0.0, 'video': 0.0}
# {'dhire': 0.0, 'bhagvan': 0.0, 'example': 0.0, 'hindu': 0.0, 'katha': 0.0, 'ramayan': 0.0, 'religion': 0.0, 'video': 0.0}
# {'career': 0.0, 'designing': 0.0, 'graphic': 0.0, 'learn': 0.0, 'persuade': 0.0}
# {'court': 0.0, 'india': 0.0, 'information': 0.0, 'please': 0.0, 'sahara': 0.0, 'supreme': 0.0, 'vedio': 0.0}
# {'5hours': 0.0, 'course': 0.0, 'karte': 0.0, 'lekin': 0.0, 'student': 0.0}
# {'granth': 0.0, 'neelvanti': 0.0, 'video': 0.0}
# {'download': 1.0}
# {'niche': 0.0, 'systumm': 0.0}
# {'please': 0.0, 'video': 0.0}
# {'apple': 0.0, 'download': 0.0, 'mobile': 0.0}
# {'video': 1.0}
# {'entering': 1.0}
# {'banao': 0.0, 'video': 0.0}
# {'plzzzzzz': 0.0, 'topic': 0.0, 'video': 0.0}
# {'funds': 0.0, 'market': 0.0, 'mutual': 0.0, 'share': 0.0, 'vedio': 0.0}
# {'download': 1.0}
# {'11:28': 0.0, 'computer': 0.0, 'karna': 0.0, 'kharab': 0.0}
# {'chatgpt': 0.0, 'company': 0.0, 'unless': 0.0}
# {'information': 0.0, 'mint': 0.0}
# {'information': 0.0, 'beast': 0.0, 'control': 0.0, 'right': 0.0, 'total': 0.0, 'wrong': 0.0}
# {'brother': 0.0, 'always': 0.0, 'banao': 0.0, 'chandryaan': 0.0, 'duniya': 0.0, 'video': 0.0, 'waiting': 0.0}
# {'bigboss': 0.0, 'blowing': 0.0, 'participate': 0.0, 'question': 0.0, 'video': 0.0}
# {'course': 0.0, 'summarize': 0.0, 'whole': 0.0}
# {'genuine': 0.0, 'words': 0.0}
# {'banao': 0.0, 'dhruv': 0.0, 'manipur': 0.0, 'please': 0.0, 'video': 0.0}
# {'please': 0.0, 'video': 0.0}
# {'banaiye': 1.0}
# {'future': 0.0, 'india': 0.0, 'mission': 0.0, 'space': 0.0, 'video': 0.0}
# {'rajasthan': 0.0, 'sheet': 0.0, 'examination': 0.0, 'municipality': 0.0, 'piss': 0.0, 'promotion': 0.0, 'question': 0.0, 'running': 0.0, 'sales': 0.0, 'selling': 0.0, 'successful': 0.0, 'youth': 0.0}
# {'please': 0.0, 'advantage': 0.0, 'brother': 0.0, 'disadvantage': 0.0, 'network': 0.0, 'video': 0.0}
# {'chala': 0.0, 'kabhi': 0.0, 'political': 0.0}
# {'banayiga': 0.0, 'vedios': 0.0}
# {'chodna': 0.0, 'jaisa': 0.0}
# {'video': 1.0}
# {'chandrayaan': 0.0, 'video': 0.0}
# {'video': 1.0}
# {'course': 0.0, 'expensive': 0.0}
# {'branch': 0.0, 'engineering': 0.0, 'robotics': 0.0}
# {'blogging': 0.0, 'change': 0.0, 'face': 0.0, 'really': 0.0}
# {'video': 1.0}
# {'dhruv': 1.0}
# {'big': 0.0, 'thanks': 0.0, 'video': 0.0}
# {'answer': 0.0, 'movie': 0.0, 'robot': 0.0, 'smith': 0.0, 'video': 0.0}
# {'dhruv': 0.0, 'dynasty': 0.0, 'education': 0.0, 'karaga': 0.0, 'mysore': 0.0, 'video': 0.0}
# {'going': 1.0}
# {'banate': 0.0, 'dhruv': 0.0, 'video': 0.0}
# {'software': 0.0, 'budhi': 0.0, 'choti': 0.0, 'device': 0.0, 'easily': 0.0, 'remove': 0.0, 'weapon': 0.0}
# {'plese': 0.0, 'secuerism': 0.0, 'vedio': 0.0}
# {'destroy': 0.0, 'future': 0.0, 'learner': 0.0}
# {'america': 0.0, 'drug': 0.0, 'video': 0.0, 'zombie': 0.0}
# {'course': 0.0, 'price': 0.0}
# {'paisa': 1.0}
# {'banau': 0.0, 'video': 0.0}
# {'video': 1.0}
# {'parde': 0.0, 'peeche': 0.0}
# {'22:00': 0.0, '21:57': 0.0, '21:58': 0.0, '22:01': 0.0}
# {'hindu': 0.0, 'despite': 0.0, 'follow': 0.0, 'religion': 0.0, 'unsubscribing': 0.0}
# {'bible': 0.0, 'dhruv': 0.0, 'issliye': 0.0, 'likha': 0.0, 'rathi': 0.0}
# {'especially': 0.0, 'impact': 0.0}
# {'engineer': 0.0, 'mirza': 0.0, 'muhammad': 0.0, 'subscribe': 0.0, 'uostad': 0.0}
# {'rupee': 0.0, 'would': 0.0, 'costs': 0.0, 'course': 0.0, 'people': 0.0, 'waste': 0.0, 'usd(not': 0.0, 'trick': 0.0, 'thought': 0.0, 'replace': 0.0, 'raathe': 0.0, 'price': 0.0, 'offer': 0.0, 'notice': 0.0, 'money': 0.0, 'meams': 0.0, '12,000': 0.0, 'hurry': 0.0, 'guide': 0.0, 'first': 0.0, 'eligible': 0.0, 'effectively': 0.0, 'doubt': 0.0, 'discount': 0.0, 'dhruv': 0.0, 'cunning': 0.0, 'creative': 0.0, 'better': 0.0, 'around': 0.0, 'whatever': 0.0, 'instead': 0.0}
# {'manipur': 0.0, 'video': 0.0}
# {'interest': 0.0, 'video': 0.0}
# {'banawo': 0.0, 'chandra': 0.0, 'death': 0.0, 'mystery': 0.0, 'subhash': 0.0, 'video': 0.0}
# {'topic': 0.0, 'video': 0.0}
# {'dhruv': 0.0, 'matrix': 0.0, 'people': 0.0, 'rathee': 0.0}
# {'information': 1.0}
# {'right': 0.0, 'terminator': 0.0}
# {'hatke': 0.0, 'hogya': 0.0, 'series': 0.0}
# {'update': 0.0, 'generation': 0.0, 'thanks': 0.0}
# {'topic': 0.0, 'video': 0.0}
# {'autism': 0.0, 'bacho': 0.0, 'information': 0.0, 'plzzz': 0.0, 'sense': 0.0}
# {'video': 1.0}
# {'computer': 0.0, 'school': 0.0, 'windows': 0.0}
# {'course': 0.0, 'competition': 0.0, 'jayenge': 0.0}
# {'actually': 0.0, 'leadzin': 0.0, 'marketing': 0.0, 'please': 0.0, 'video': 0.0}
# {'money': 0.0, 'skill': 0.0, 'video': 0.0}
# {'moose': 0.0, 'sidhu': 0.0, 'singer': 0.0, 'video': 0.0}
# {'banao': 0.0, 'video': 0.0}
# {'brother': 0.0, 'great': 0.0, 'information': 0.0, 'useful': 0.0}
# {'chatgpt': 0.0, 'need': 0.0, 'oversee': 0.0, 'someone': 0.0}
# {'google': 0.0, 'server': 0.0, 'dedeta': 0.0, 'result': 0.0, 'processing': 0.0, 'nothing': 0.0, 'modify': 0.0, 'machine': 0.0, 'maanlo': 0.0, 'karega': 0.0, 'human': 0.0, 'banaya': 0.0, 'ghnta': 0.0, 'duniyan': 0.0, 'dominate': 0.0, 'design': 0.0, 'create': 0.0, 'collect': 0.0, 'brain': 0.0, 'bloody': 0.0, 'bhasad': 0.0, 'smart': 0.0, 'speed': 0.0}
# {'video': 1.0}
# {'video': 0.0, 'amount': 0.0, 'chapter': 0.0, 'ethics': 0.0, 'giving': 0.0, 'knowledge': 0.0, 'occur': 0.0, 'please': 0.0, 'priceless': 0.0, 'religious': 0.0, 'unimaginable': 0.0}
# {'barry': 0.0, 'contact': 0.0, 'course': 0.0, 'sakte': 0.0}
# {'course': 0.0, 'taking': 0.0, 'worth': 0.0}
# {'course': 0.0, 'dhruv': 0.0, 'rathee': 0.0}
# {'aapse': 0.0, 'krnahai': 0.0, 'mujhe': 0.0, 'sikhnahai': 0.0}
# {'brother': 0.0, 'janakari': 0.0, 'kmaal': 0.0, 'sabko': 0.0, 'thanx': 0.0}
# {'arahi': 0.0, 'bless': 0.0, 'bohat': 0.0, 'chahene': 0.0, 'jayenge': 0.0, 'khabar': 0.0, 'khayal': 0.0}
# {'hours': 0.0, 'reading': 0.0}
# {'please': 0.0, 'great': 0.0, 'teacher': 0.0, 'video': 0.0}
# {'please': 0.0, 'video': 0.0}
# {'please': 0.0, 'video': 0.0}
# {'bejhte': 0.0, 'course': 0.0, 'gharwale': 0.0, 'jaayega': 0.0, 'karne': 0.0, 'khane': 0.0, 'kharcha': 0.0, 'mahine': 0.0, 'peene': 0.0, 'sasta': 0.0, 'thoda': 0.0}
# {'develop': 0.0, 'movie': 0.0, 'mushkil': 0.0}
# {'-unknown': 0.0, 'person': 0.0}
# {'reality': 0.0, 'seem': 0.0, 'title': 0.0}
# {'become': 0.0, 'command': 0.0, 'dangerous': 0.0, 'people': 0.0, 'start': 0.0}
# {'bhaiya': 0.0, 'dijiye': 0.0, 'video': 0.0}
# {'banao': 0.0, 'batao': 0.0, 'fayda': 0.0, 'jisme': 0.0, 'video': 0.0}
# {'video': 1.0}
# {'hindi': 0.0, 'video': 0.0, 'bangladesh': 0.0, 'english': 0.0, 'friend': 0.0, 'little': 0.0, 'properly': 0.0, 'suitable': 0.0, 'translate': 0.0}
# {'wish': 1.0}
# {'bigboss': 1.0}
# {'asieee': 0.0, 'banyee': 0.0, 'pakistan': 0.0, 'please': 0.0, 'video': 0.0}
# {'batte': 0.0, 'jarurat': 0.0, 'jsise': 0.0, 'khutke': 0.0, 'mentor': 0.0, 'negative': 0.0, 'positive': 0.0, 'thank': 0.0}
# {'charge': 0.0, 'course': 0.0}
# {'aapka': 0.0, 'aapne': 0.0, 'farjibada': 0.0, 'government': 0.0, 'karethankyou': 0.0, 'madhyam': 0.0, 'patwari': 0.0, 'please': 0.0, 'prakat': 0.0, 'sochte': 0.0, 'video': 0.0}
# {'knowl': 0.0, 'polytheism': 0.0, 'question': 0.0, 'start': 0.0}
# {'create': 0.0, 'order': 0.0, 'world': 0.0}
# {'chaahiye': 0.0, 'course': 0.0}
# {'precaution': 0.0, 'safety': 0.0, 'video': 0.0}
# {'nepal': 1.0}
# {'content': 0.0, 'topic': 0.0}
# {'dhruv': 0.0, 'entry': 0.0}
# {'chatgpt': 0.0, 'machine': 0.0, 'money': 0.0}
# {'jroor': 0.0, 'minute': 0.0, 'pragyanam': 0.0, 'visit': 0.0}
# {'bakwaas': 0.0, 'batai': 0.0, 'coding': 0.0, 'development': 0.0, 'fullstack': 0.0, 'hamare': 0.0, 'jaisa': 0.0, 'krenge': 0.0, 'mahan': 0.0, 'paper': 0.0, 'teacher': 0.0, 'university': 0.0, 'waisa': 0.0}
# {'dhruv': 0.0, 'please': 0.0, 'rathee': 0.0, 'topic': 0.0, 'video': 0.0}
# {'bigboss': 0.0, 'please': 0.0}
# {'video': 1.0}
# {'aaiye': 0.0, 'bakwas': 0.0, 'jagah': 0.0, 'plzzzz': 0.0}
# {'dhruv': 0.0, 'emerge': 0.0, 'folks': 0.0, 'learning': 0.0, 'machine': 0.0, 'newly': 0.0, 'rathee': 0.0, 'revolution': 0.0, 'thanks': 0.0, 'upcoming': 0.0, 'update': 0.0, 'video': 0.0}
# {'chahiye': 0.0, 'tumko': 0.0}
# {'learning': 0.0, 'machine': 0.0, 'relate': 0.0, 'topic': 0.0, 'video': 0.0}
# {'banawo': 0.0, 'metrology': 0.0, 'report': 0.0, 'video': 0.0, 'weather': 0.0}
# {'artificial': 0.0, 'intelligence': 0.0, 'another': 0.0, 'every': 0.0, 'everyone': 0.0, 'feel': 0.0, 'please': 0.0, 'proud': 0.0, 'share': 0.0, 'video': 0.0}
# {'video': 1.0}
# {'video': 1.0}
# {'digital': 0.0, 'marketing': 0.0, 'banao': 0.0, 'bizgurukul': 0.0, 'content': 0.0, 'earn': 0.0, 'learning': 0.0, 'plateform': 0.0}
# {'movie': 0.0, 'remember': 0.0, 'robot': 0.0}
# {'please': 1.0}
# {'banao': 0.0, 'seema': 0.0, 'video': 0.0}
# {'industry': 0.0, 'petrolium': 0.0, 'please': 0.0, 'video': 0.0}
# {'adzal': 0.0, 'dhruv': 0.0, 'jankari': 0.0, 'mujhe': 0.0, 'reality': 0.0, 'story': 0.0}
# {'please': 0.0, '50000': 0.0, 'account': 0.0, 'bheek': 0.0, 'depress': 0.0, 'maang': 0.0, 'madat': 0.0, 'suicide': 0.0, 'thinking': 0.0}
# {'badhiya': 0.0, 'hrithik': 0.0, 'roshan': 0.0}
# {'chandrayaan': 0.0, 'video': 0.0}
# {'fact': 0.0, 'relate': 0.0, 'sound': 0.0, 'tragic': 0.0, 'video': 0.0, 'whale': 0.0}
# {'banao': 0.0, 'kahte': 0.0, 'video': 0.0}
# {'bataie': 0.0, 'details': 0.0}
# {'artificial': 0.0, 'intelligence': 0.0, 'vedios': 0.0}
# {'curious': 0.0, 'topic': 0.0, 'video': 0.0}
# {'humans': 0.0, 'technology': 0.0}
# {'content': 0.0, 'personally': 0.0, 'really': 0.0}
# {'course': 0.0, 'dhruv': 0.0, 'making': 0.0, 'rathee': 0.0, 'using': 0.0}
# {'chatgpt': 0.0, 'right': 0.0, 'workin': 0.0}
# {'number': 1.0}
# {'community': 0.0, 'dominate': 0.0, 'human': 0.0, 'possible': 0.0, 'robot': 0.0}
# {'please': 0.0, 'video': 0.0}
# {'bahut': 0.0, 'course': 0.0, 'coust': 0.0}
# {'create': 0.0, 'farming': 0.0, 'joining': 0.0, 'kaise': 0.0, 'organic': 0.0, 'people': 0.0, 'powerful': 0.0, 'price': 0.0, 'rich': 0.0}
# {'account': 0.0, 'create': 0.0, 'lees': 0.0, 'years': 0.0}
# {'admire': 0.0, 'cheap': 0.0, 'course': 0.0, 'dhruv': 0.0, 'expect': 0.0, 'please': 0.0, 'stunt': 0.0, 'video': 0.0}
# {'ajmer': 0.0, 'video': 0.0}
# {'bataaiye': 0.0, 'factory': 0.0, 'founder': 0.0, 'innovation': 0.0}
# {'jerman': 0.0, 'shepherd': 0.0}
# {'banaeye': 0.0, 'dhruv': 0.0, 'rathee': 0.0, 'sachin': 0.0, 'seema': 0.0, 'story': 0.0, 'video': 0.0}
# {'future': 0.0, 'human': 0.0, 'really': 0.0, 'replace': 0.0, 'robot': 0.0, 'scary': 0.0, 'topic': 0.0}
# {'danger': 0.0, 'deadly': 0.0, 'future': 0.0, 'human': 0.0, 'impact': 0.0, 'large': 0.0, 'military': 0.0, 'replace': 0.0, 'robot': 0.0, 'soldier': 0.0, 'world': 0.0}
# {'court': 0.0, 'haryana': 0.0, 'punjab': 0.0}
# {'money': 0.0, 'nigga': 0.0}
# {'change': 0.0, 'jisse': 0.0, 'sakta': 0.0, 'smile': 0.0}
# {'number': 0.0, 'class': 0.0, 'mujhe': 0.0, 'phone': 0.0, 'please': 0.0}
# {'chandrayan': 0.0, 'video': 0.0}
# {'people': 0.0, 'educate': 0.0, 'please': 0.0, 'request': 0.0, 'uneducated': 0.0}
# {'branch': 0.0, 'choose': 0.0, 'student': 0.0}
# {'haider': 0.0, 'pakistan': 0.0, 'please': 0.0, 'seema': 0.0, 'video': 0.0}
# {'ambani': 0.0, 'coropt': 0.0, 'karenge': 0.0, 'story': 0.0}
# {'course': 0.0, 'excite': 0.0, 'learn': 0.0, 'people': 0.0, 'price': 0.0, 'think': 0.0}
# {'video': 1.0}
# {'waiting': 1.0}
# {'deepfake': 0.0, 'woman': 0.0, 'cover': 0.0, 'girl': 0.0, 'please': 0.0, 'safety': 0.0, 'threat': 0.0, 'video': 0.0}
# {'video': 1.0}
# {'topic': 0.0, 'vedioes': 0.0}
# {'aapki': 0.0, 'acchi': 0.0, 'comment': 0.0, 'dhruv': 0.0, 'karte': 0.0, 'lekin': 0.0, 'mujhe': 0.0, 'replay': 0.0, 'video': 0.0}
# {'banayen': 0.0, 'point': 0.0, 'video': 0.0}
# {'appreciate': 0.0, 'india': 0.0, 'representa': 0.0}
# {'ajmer': 0.0, 'video': 0.0}
# {'hamare': 0.0, 'paishe': 0.0, 'student': 0.0}
# {'course': 0.0, 'english': 0.0, 'hindi': 0.0}
# {'tumko': 0.0, 'dhruv': 0.0, 'factbhai': 0.0, 'pathai': 0.0, 'rathee': 0.0, 'view': 0.0}
# {'competition': 0.0, 'recitation': 0.0}
# {'nepal': 0.0, 'ppmpop': 0.0, 'radea': 0.0, 'rapper': 0.0}
# {'bigboss': 0.0, 'dhruv': 0.0, 'rathee': 0.0}
# {'banaye': 0.0, 'video': 0.0}
# {'22:00': 0.0, 'bohot': 0.0, 'mehnga': 0.0}
# {'accord': 1.0}
# {'expect': 0.0, 'informative': 0.0, 'thanks': 0.0, 'video': 0.0}
# {'banana': 0.0, 'padega': 0.0, 'pasand': 0.0, 'video': 0.0}
# {'crypto': 1.0}
# {'interest': 0.0, 'learn': 0.0, 'please': 0.0, 'video': 0.0}
# {'information': 0.0, 'share': 0.0}
# {'capability': 0.0, 'develop': 0.0}
# {'aarhee': 1.0}
# {'generator': 0.0, 'robot': 0.0}
# {'concept': 0.0, 'dhruv': 0.0, 'fact': 0.0, 'future': 0.0, 'india': 0.0, 'rathi': 0.0, 'really': 0.0, 'telling': 0.0, 'thank': 0.0, 'video': 0.0, 'working': 0.0, 'would': 0.0}
# {'humans': 0.0, 'world': 0.0, 'active': 0.0, 'afraid': 0.0, 'beautiful': 0.0, 'destroy': 0.0, 'earth': 0.0, 'going': 0.0, 'lovely': 0.0, 'parts': 0.0, 'power': 0.0, 'series': 0.0, 'terminator': 0.0}
# {'please': 0.0, 'reallly': 0.0, 'technology': 0.0, 'topic': 0.0, 'video': 0.0}
# {'knowledge': 0.0, 'share': 0.0}
# {'goverment': 0.0, 'amount': 0.0, 'chahiye': 0.0, 'government': 0.0, 'hindu': 0.0, 'indian': 0.0, 'insan': 0.0, 'muslim': 0.0, 'online': 0.0, 'paisa': 0.0, 'parva': 0.0, 'satta': 0.0, 'scammer': 0.0}
# {'aapna': 0.0, 'agenda': 0.0, 'chodna': 0.0}
# {'gulam': 0.0, 'karwa': 0.0, 'robot': 0.0}
# {'entering': 0.0, 'physical': 0.0, 'altercation': 0.0, 'thingsone': 0.0, 'surprise': 0.0, 'succeedtake': 0.0, 'since': 0.0, 'seem': 0.0, 'remember': 0.0, 'place': 0.0, 'necessary': 0.0, 'involve': 0.0, 'include': 0.0, 'house': 0.0, 'fight': 0.0, 'dhruv': 0.0, 'come': 0.0, 'clown': 0.0, 'assault': 0.0, 'though': 0.0, 'usually': 0.0}
# {'video': 1.0}
# {'dhruv': 0.0, 'imran': 0.0, 'interview': 0.0}
# {'video': 1.0}
# {'anchor': 0.0, 'different': 0.0, 'launch': 0.0, 'look': 0.0, 'odisha': 0.0, 'outfit': 0.0, 'state': 0.0, 'wear': 0.0}
# {'france': 0.0, 'riot': 0.0, 'video': 0.0}
# {'video': 1.0}
# {'change': 0.0, 'photo': 0.0, 'ritik': 0.0, 'roshan': 0.0}
# {'bengol': 0.0, 'joine': 0.0, 'kasay': 0.0}
# {'consider': 0.0, 'grade': 0.0, 'student': 0.0, 'video': 0.0}
# {'apply': 0.0, 'cources': 0.0, 'course': 0.0, 'kindly': 0.0, 'lower': 0.0, 'request': 0.0, 'student': 0.0, 'thought': 0.0, 'upcoming': 0.0}
# {'bnayen': 0.0, 'video': 0.0}
# {'alisha': 0.0, 'video': 0.0}
# {'afford': 0.0, 'course': 0.0, 'playlist': 0.0, 'please': 0.0}
# {'chandrayan': 0.0, 'aajate': 0.0, 'bhaiyaaap': 0.0, 'bhiaapki': 0.0, 'dijiyeor': 0.0, 'hello': 0.0, 'history': 0.0, 'india': 0.0, 'lonch': 0.0, 'video': 0.0}
# {'bhaiya': 0.0, 'dhruv': 0.0, 'person': 0.0, 'simple': 0.0}
# {'banao': 1.0}
# {'chahenge': 0.0, 'dekhna': 0.0, 'dhruv': 0.0, 'jarur': 0.0}
# {'france': 0.0, 'riot': 0.0, 'video': 0.0, 'india': 0.0, 'lekin': 0.0, 'turant': 0.0}
# {'banaiye': 0.0, 'haider': 0.0, 'sheema': 0.0, 'video': 0.0}
# {'better': 0.0, 'explain': 0.0, 'please': 0.0, 'teacher': 0.0, 'topic': 0.0, 'video': 0.0}
# {'develop': 0.0, 'dntdenotify': 0.0, 'tribe': 0.0, 'unable': 0.0, 'video': 0.0}
# {'bigboss': 0.0, 'jaanewale': 0.0}
# {'worst': 0.0, 'business': 0.0, 'child': 0.0, 'collapse': 0.0, 'education': 0.0, 'entire': 0.0, 'making': 0.0, 'system': 0.0, 'think': 0.0}
# {'baitha': 0.0, 'batata': 0.0, 'batayga': 0.0, 'bhagwan': 0.0, 'jhooti': 0.0, 'karta': 0.0, 'kitna': 0.0, 'mardarchod': 0.0, 'pakistan': 0.0, 'support': 0.0}
# {'hazir': 0.0, 'karoge': 0.0, 'manipur': 0.0, 'study': 0.0}
# {'ritik': 0.0, 'rosan': 0.0}
# {'aapka': 0.0, 'comment': 0.0, 'kyuki': 0.0, 'padhte': 0.0, 'video': 0.0}
# {'budget': 0.0, 'course': 0.0, 'expensive': 0.0, 'money': 0.0, 'think': 0.0, 'worth': 0.0}
# {'cours': 0.0, 'laptop': 0.0, 'login': 0.0, 'necessary': 0.0, 'number': 0.0, 'phone': 0.0}
# {'branch': 1.0}
# {'video': 1.0}
# {'admit': 0.0, 'bageshwar': 0.0, 'dhruv': 0.0, 'fraud': 0.0}
# {'dhruv': 0.0, 'rathee': 0.0}
# {'document': 0.0, 'banake': 0.0, 'unpar': 0.0, 'thura': 0.0, 'pakistan': 0.0, 'larke': 0.0, 'india': 0.0, 'hogaapp': 0.0, 'force': 0.0, 'farzhi': 0.0, 'dukrahe': 0.0, 'dekhe': 0.0, 'chalrahi': 0.0, 'bengal': 0.0, 'bataw': 0.0, 'bangladesh': 0.0, 'varthi': 0.0, 'verification': 0.0}
# {'jaate': 0.0, 'useless': 0.0}
# {'india': 0.0, 'reporting': 0.0}
# {'please': 1.0}
# {'nation': 0.0, 'thought': 0.0}
# {'chandrayaan': 0.0, 'please': 0.0, 'reach': 0.0, 'video': 0.0, 'would': 0.0}
# {'alimirza': 0.0, 'bahii': 0.0, 'dhruv': 0.0, 'engineer': 0.0, 'karen': 0.0, 'muhammad': 0.0, 'podcast': 0.0, 'sahib': 0.0}
# {'dangerous': 0.0, 'humanity': 0.0, 'listen': 0.0, 'really': 0.0}
# {'aisha': 0.0, 'jeevan': 0.0, 'kaise': 0.0, 'mohomad': 0.0, 'popat': 0.0, 'video': 0.0, 'years': 0.0}
# {'content': 0.0, 'provide': 0.0, 'affect': 0.0, 'charge': 0.0, 'eventually': 0.0, 'expert': 0.0, 'greedy': 0.0, 'hefty': 0.0, 'neutral': 0.0, 'present': 0.0, 'supporter': 0.0, 'video': 0.0}
# {'future': 0.0, 'please': 0.0}
# {'dhruv': 0.0, 'google': 0.0, 'karta': 0.0, 'paste': 0.0}
# {'afwah': 0.0, 'arahe': 0.0}
# {'muhammad': 0.0, 'please': 0.0, 'prophet': 0.0, 'video': 0.0}
# {'rahega': 0.0, 'samay': 0.0, 'viswas': 0.0}
# {'bigboss': 0.0, 'dhruv': 0.0, 'going': 0.0}
# {'topic': 0.0, 'video': 0.0}
# {'create': 0.0, 'series': 0.0}
# {'altron': 0.0, 'jayega': 0.0, 'scene': 0.0}
# {'biggboss': 0.0, 'going': 0.0}
# {'topic': 0.0, 'video': 0.0}
# {'conquer': 0.0, 'dikhaya': 0.0, 'duniya': 0.0, 'kaise': 0.0, 'machine': 0.0, 'matrix': 0.0, 'movie': 0.0}
# {'please': 0.0, 'video': 0.0}
# {'likha': 0.0, 'agree': 0.0, 'dheere': 0.0, 'banda': 0.0, 'brain': 0.0, 'dikha': 0.0, 'haijai': 0.0, 'leftist': 0.0, 'likhe': 0.0, 'pddta': 0.0, 'smjho': 0.0, 'terrorist': 0.0}
# {'create': 0.0, 'please': 0.0, 'video': 0.0}
# {'beautiful': 0.0, "can't": 0.0, 'create': 0.0, 'death': 0.0, 'everything': 0.0, 'imortal': 0.0, 'modify': 0.0, 'mother': 0.0, 'rebirth': 0.0, 'truth': 0.0}
# {'prshan': 1.0}
# {'course': 0.0, 'bohot': 0.0, 'price': 0.0, '80%ya90': 0.0, 'nukshan': 0.0, 'minimum': 0.0, 'maximum': 0.0, 'lakin': 0.0, 'karoge': 0.0, 'karna': 0.0, 'india': 0.0, 'hisab': 0.0, 'faisa': 0.0, 'customer': 0.0, 'costomer': 0.0, 'chahte': 0.0, 'jaige': 0.0, 'subscriber': 0.0}
# {'explaine': 1.0}
# {'topic': 0.0, 'video': 0.0}
# {'learn': 0.0, 'please': 0.0, 'wanna': 0.0}
# {'bahot': 0.0, 'medium': 0.0, 'recently': 0.0, 'social': 0.0}
# {'sahab': 0.0, 'ststumm': 0.0}
# {'please': 0.0, 'video': 0.0}
# {'bnnaoo': 0.0, 'video': 0.0}
# {'please': 0.0, 'topic': 0.0}
# {'haijarvis': 0.0, 'lauch': 0.0, 'stark': 0.0}
# {'daimond': 0.0, 'video': 0.0, 'banav': 0.0, 'bante': 0.0, 'information': 0.0, 'kitne': 0.0, 'rubii': 0.0}
# {'department': 0.0, 'national': 0.0, 'statistics': 0.0, 'thanks': 0.0}
# {'bahana': 0.0, 'bechne': 0.0, 'course': 0.0, 'promotion': 0.0, 'strategy': 0.0, 'video': 0.0}
# {'chaiye': 0.0, 'video': 0.0}
# {'architect': 0.0, 'bareme': 0.0, 'khayal': 0.0}
# {'impressive': 0.0, 'informative': 0.0, 'pakistan': 0.0, 'politeness': 0.0, 'teaching': 0.0, 'video': 0.0, 'voice': 0.0}
# {'video': 1.0}
# {'please': 0.0, 'video': 0.0}
# {'banaye': 0.0, 'dhruv': 0.0, 'muhammad': 0.0, 'please': 0.0, 'prophet': 0.0, 'video': 0.0}
# {'bigboss': 0.0, 'dhruv': 0.0, 'going': 0.0}
# {'coming': 1.0}
# {'amount': 0.0, 'certify': 0.0, 'charge': 0.0, 'cheap': 0.0, 'course': 0.0, 'reduce': 0.0, 'relate': 0.0}
# {'course': 0.0, 'start': 0.0}
# {'video': 1.0}
# {'available': 0.0, 'payment': 0.0, 'showing': 0.0, 'upcoming': 0.0, 'workshop': 0.0}
# {'terminator': 0.0, 'welcome': 0.0}
# {'addiction': 0.0, 'crypto': 0.0, 'earn': 0.0, 'either': 0.0, 'enlighting': 0.0, 'episode': 0.0, 'especially': 0.0, 'exchange': 0.0, 'fantastic': 0.0, 'gambling': 0.0, 'model': 0.0, 'monitor': 0.0, 'whether': 0.0}
# {'aadmi': 0.0, 'batao': 0.0, 'parti': 0.0}
# {'dhruv': 0.0, 'rathee': 0.0}
# {'bareme': 0.0, 'civil': 0.0, 'kuchto': 0.0, 'manipur': 0.0}
# {'purpose': 0.0, 'bring': 0.0, 'defeated': 0.0, 'life': 0.0, 'people': 0.0, 'pleasure': 0.0, 'satisfaction': 0.0, 'share': 0.0}
# {'bhoot': 0.0, 'village': 0.0, 'kissi': 0.0, 'aatma': 0.0, 'topic': 0.0, 'thodi': 0.0, 'research': 0.0, 'khatam': 0.0, 'karti': 0.0, 'ghost': 0.0, 'expose': 0.0, 'chahta': 0.0, 'bharat': 0.0, 'banke': 0.0, 'bahut': 0.0, 'ander': 0.0, 'viswash': 0.0, 'wishwash': 0.0}
# {'bhoot': 0.0, 'village': 0.0, 'kissi': 0.0, 'aatma': 0.0, 'topic': 0.0, 'thodi': 0.0, 'research': 0.0, 'khatam': 0.0, 'karti': 0.0, 'ghost': 0.0, 'expose': 0.0, 'chahta': 0.0, 'bharat': 0.0, 'banke': 0.0, 'bahut': 0.0, 'ander': 0.0, 'viswash': 0.0, 'wishwash': 0.0}
# {'authentic': 0.0, 'bolta': 0.0, 'brain': 0.0, 'chahta': 0.0, 'india': 0.0, 'internet': 0.0, 'ladka': 0.0, 'sahab': 0.0, 'thodi': 0.0, 'tujhe': 0.0}
# {'please': 0.0, 'bigboss': 0.0}
# {'dhruv': 0.0, 'look': 0.0, 'rathee': 0.0}
# {'class': 0.0, 'master': 0.0}
# {'aadmiyon': 0.0, 'dunia': 0.0, 'khatm': 0.0, 'lgenge': 0.0, 'marne': 0.0}
# {'affect': 0.0, 'please': 0.0, 'society': 0.0, 'video': 0.0}
# {'video': 0.0, '21:35': 0.0, 'awesome': 0.0, 'easily': 0.0, 'explanation': 0.0, 'life': 0.0, 'relate': 0.0, 'thankfully': 0.0, 'topic': 0.0}
# {'aapko': 0.0, 'bahut': 0.0, 'chahiye': 0.0, 'chatgpt': 0.0, 'cheap': 0.0, 'course': 0.0, 'dhruv': 0.0, 'price': 0.0, 'sakta': 0.0}
# {'course': 0.0, 'dijiyega': 0.0, 'hindi': 0.0, 'language': 0.0, 'please': 0.0}
# {'afford': 0.0, 'cource': 0.0}
# {'please': 0.0, 'video': 0.0}
# {'besabri': 0.0, 'intezar': 0.0}
# {'cruise': 0.0, 'hrithik': 0.0, 'roshan': 0.0, 'second': 0.0, 'similar': 0.0}
# {'konsi': 0.0, 'music': 0.0, 'please': 0.0, 'website': 0.0}
# {'great': 0.0, 'information': 0.0, 'thanks': 0.0}
# {'favourite': 0.0, 'please': 0.0, 'teacher': 0.0, 'video': 0.0, 'youtuber': 0.0}
# {'sakte': 0.0, 'dependent': 0.0, 'please': 0.0, 'purchase': 0.0, 'reply': 0.0, 'sirkhud': 0.0}
# {'sakte': 0.0, 'dependent': 0.0, 'please': 0.0, 'purchase': 0.0, 'reply': 0.0, 'sirkhud': 0.0}
# {'sakte': 0.0, 'dependent': 0.0, 'please': 0.0, 'purchase': 0.0, 'reply': 0.0, 'sirkhud': 0.0}
# {'please': 0.0, 'topic': 0.0, 'video': 0.0}
# {'immortality': 0.0, 'machine': 0.0, 'money': 0.0, 'people': 0.0, 'science': 0.0}
# {'knowledgable': 0.0, 'useful': 0.0, 'vedios': 0.0}
# {'asaani': 0.0, 'chatgpt': 0.0, 'chuka': 0.0, 'please': 0.0, 'register': 0.0, 'review': 0.0}
# {'money': 0.0, 'spend': 0.0, 'total': 0.0, 'waste': 0.0}
# {'banaeye': 0.0, 'topic': 0.0}
# {'another': 0.0, 'video': 0.0}
# {'course': 0.0, 'chatgpt': 0.0, 'sheet': 0.0, 'prompt': 0.0, '299/-': 0.0, 'video': 0.0, 'useful': 0.0, 'usage': 0.0, 'shallow': 0.0, 'repent': 0.0, 'waste': 0.0, 'little': 0.0, 'money': 0.0, 'buy': 0.0, 'insistence': 0.0, 'google': 0.0, 'nothing': 0.0, 'please': 0.0, 'poorly': 0.0, 'price': 0.0, 'freely': 0.0, 'effective': 0.0, 'don"t': 0.0, 'sheer': 0.0, 'design': 0.0, 'cheat': 0.0, 'available': 0.0, 'internet': 0.0, 'worth': 0.0}
# {'topic': 0.0, 'video': 0.0}
# {'video': 1.0}
# {'course': 0.0, 'thoda': 0.0, 'zyada': 0.0}
# {'aapmt': 1.0}
# {'chatgpt': 0.0, 'class': 0.0, 'course': 0.0, 'janna': 0.0, 'purchase': 0.0, 'sirmujhe': 0.0}
# {'bhaiya': 1.0}
# {'please': 0.0, 'tomato': 0.0, 'video': 0.0}
# {'video': 1.0}
# {'dhruv': 0.0, 'hindu': 0.0, 'rathi': 0.0}
# {'topic': 0.0, 'video': 0.0}
# {'video': 0.0, '3rest': 0.0, 'appreciate': 0.0, 'chandriyaan': 0.0, 'channels': 0.0, 'thatwe': 0.0, 'unbiased': 0.0}
# {'banaye': 0.0, 'video': 0.0}
# {'dhruve': 0.0, 'manipulate': 0.0}
# {'create': 0.0, 'philosophical': 0.0, 'please': 0.0, 'video': 0.0}
# {'killing': 0.0, 'restrict': 0.0, 'silution': 0.0, 'technologyor': 0.0}
# {'continue': 0.0, 'please': 0.0, 'video': 0.0}
# {'hamare': 0.0, 'khilaf': 0.0, 'banao': 0.0, 'chahiye': 0.0, 'jankari': 0.0, 'lgbtq': 0.0, 'majhab': 0.0, 'video': 0.0}
# {'banaiye': 0.0, 'chandrayan': 0.0, 'video': 0.0}
# {'video': 0.0, 'want': 0.0}
# {'alliance': 0.0, 'dhruve': 0.0, 'opposition': 0.0, 'party': 0.0, 'please': 0.0, 'video': 0.0}
# {'american': 0.0, 'joseph': 0.0, 'lawrence': 0.0, 'please': 0.0, 'professor': 0.0, 'research': 0.0, 'samjaye': 0.0, 'video': 0.0}
# {'bahut': 0.0, 'funny': 0.0, 'starting': 0.0, 'video': 0.0}
# {'adsense': 0.0, 'approval': 0.0, 'article': 0.0, 'blogging': 0.0, 'chatgpt': 0.0, 'jayegi': 0.0, 'kyunki': 0.0, 'likhna': 0.0, 'madad': 0.0, 'milega': 0.0, 'ranking': 0.0, 'tumhari': 0.0}
# {'banao': 0.0, 'behatar': 0.0, 'every': 0.0, 'facility': 0.0, 'future': 0.0, 'gareebi': 0.0, 'hospital': 0.0, 'india': 0.0, 'indian': 0.0, 'khatam': 0.0, 'layak': 0.0, 'rahne': 0.0, 'rojghar': 0.0, 'sudhar': 0.0, 'thoda': 0.0}
# {'people': 0.0, 'adopt': 0.0, 'awering': 0.0, 'future': 0.0, 'give': 0.0, 'happen': 0.0, 'right': 0.0, 'salute': 0.0, 'thank': 0.0, 'things': 0.0, 'thought': 0.0}
# {'control': 0.0, 'death': 0.0, 'dhruv': 0.0, 'please': 0.0, 'video': 0.0}
# {'brother': 0.0, 'dhruv': 0.0, 'entry': 0.0, 'going': 0.0, 'please': 0.0}
# {'banaiye': 0.0, 'please': 0.0, 'video': 0.0}
# {'destroy': 0.0, 'world': 0.0}
# {'dhurv': 0.0, 'rathi': 0.0}
# {'bhaiya': 0.0, 'galat': 0.0}
# {'entry': 1.0}
# {'price': 0.0, '1000se': 0.0, '1500rs': 0.0, 'aisaa': 0.0, 'bahut': 0.0, 'milte': 0.0, 'minimum': 0.0, 'money': 0.0, 'month': 0.0, 'passout': 0.0, 'pawngaplease': 0.0, 'pocket': 0.0, 'rupee': 0.0, 'student': 0.0}
# {'effects': 0.0, 'especially': 0.0, 'girl': 0.0, 'harmful': 0.0, 'please': 0.0, 'video': 0.0}
# {'bangladesh': 0.0, 'course': 0.0, 'possible': 0.0}
# {'baremain': 0.0, 'bharti': 0.0, 'explain': 0.0, 'gandhi': 0.0, 'keshvanand': 0.0, 'menka': 0.0, 'study': 0.0}
# {'chatgpt': 0.0, 'clear': 0.0, 'thanks': 0.0}
# {'banao': 0.0, 'batao': 0.0, 'dhruv': 0.0, 'explain': 0.0, 'kailash': 0.0, 'karke': 0.0, 'parvat': 0.0, 'please': 0.0, 'rathee': 0.0, 'sakte': 0.0, 'uppar': 0.0, 'video': 0.0}
# {'banao': 0.0, 'batao': 0.0, 'dhruv': 0.0, 'explain': 0.0, 'kailash': 0.0, 'karke': 0.0, 'parvat': 0.0, 'please': 0.0, 'rathee': 0.0, 'sakte': 0.0, 'uppar': 0.0, 'video': 0.0}
# {'informative': 0.0, 'video': 0.0}
# {'party': 0.0, 'bhaiya': 0.0, 'neutral': 0.0, 'like': 0.0, 'kejri': 0.0, 'karta': 0.0, 'karna': 0.0, 'system': 0.0, 'jaanta': 0.0, 'dikhaoge': 0.0, 'development': 0.0, 'delhi': 0.0, 'criticise': 0.0, 'burai': 0.0, 'brother': 0.0, 'drainage': 0.0, 'video': 0.0}
# {'ravish': 1.0}
# {'detail': 0.0, 'please': 0.0, 'video': 0.0}
# {'bhaiya': 0.0, 'ldkiyon': 0.0, 'misuse': 0.0}
# {'ladkiya': 0.0, 'misuse': 0.0, 'sakti': 0.0}
# {'acording': 0.0, 'census': 0.0, 'giving': 0.0, 'increasment': 0.0, 'india': 0.0, 'information': 0.0, 'literacy': 0.0, 'wrong': 0.0}
# {'course': 0.0, 'money': 0.0, 'student': 0.0}
# {'please': 0.0, 'tool': 0.0, 'useful': 0.0, 'video': 0.0}
# {'afford': 0.0, 'daily': 0.0, 'genius': 0.0}
# {'video': 1.0}
# {'thank': 1.0}
# {'topic': 0.0, 'video': 0.0}
# {'chatgpt': 0.0, 'computer': 0.0, 'learn': 0.0, 'marketing': 0.0, 'minutes': 0.0, 'online': 0.0, 'reality': 0.0, 'skill': 0.0, 'teach': 0.0, 'using': 0.0}
# {'money': 1.0}
# {'version': 0.0, 'chatgpt': 0.0}
# {'looking': 0.0, 'rithik': 0.0, 'roshan': 0.0}
# {'kiski': 0.0, 'dekhne': 0.0}
# {'banoge': 0.0, 'hairder': 0.0, 'seema': 0.0, 'vedio': 0.0}
# {'costly': 0.0, 'course': 0.0, 'student': 0.0}
# {'ayoge': 0.0, 'bbott2': 0.0, 'dhruv': 0.0, 'rathee': 0.0}
# {'adipurush': 0.0, 'banta': 0.0, 'kharab': 0.0}
# {'coming': 0.0, 'world': 0.0}
# {'alliance': 0.0, 'dhruv': 0.0, 'indian': 0.0, 'video': 0.0}
# {'kitne': 0.0, 'krega': 0.0, 'thumbnail': 0.0, 'update': 0.0, 'video': 0.0}
# {'child': 0.0, 'jungle': 0.0, 'large': 0.0, 'survive': 0.0, 'world': 0.0}
# {'arrival': 0.0, 'dajjal': 0.0}
# {'minutes': 1.0}
# {'channel': 0.0, 'english': 0.0}
# {'banayia': 0.0, 'story': 0.0}
# {'topicc': 1.0}
# {'artificial': 0.0, 'intelligence': 0.0, 'video': 0.0}
# {'highly': 0.0, 'intelligent': 0.0}
# {'complete': 0.0, 'amaze': 0.0, 'though': 0.0, 'third': 0.0, 'thing': 0.0, 'sound': 0.0, 'sitting': 0.0, 'quite': 0.0, 'please': 0.0, 'otherwise': 0.0, 'liberty': 0.0, 'karne': 0.0, 'join': 0.0, 'hoon"-': 0.0, 'friend': 0.0, 'elder': 0.0, 'course': 0.0, 'correct': 0.0, 'conversation': 0.0, 'context': 0.0, 'believe': 0.0, 'thought': 0.0, 'want': 0.0}
# {'hijde': 0.0, 'bajaye': 0.0}
# {'education': 0.0, 'important': 0.0}
# {'dhruv': 0.0, 'educate': 0.0, 'fact': 0.0, 'informative': 0.0, 'please': 0.0, 'topic': 0.0, 'unheard': 0.0, 'video': 0.0}
# {'perfect': 0.0, 'video': 0.0}
# {'aadami': 0.0, 'bakhiya': 0.0, 'channel': 0.0, 'dhruv': 0.0, 'explain': 0.0, 'jawab': 0.0, 'kyunki': 0.0, 'party': 0.0, 'rathee': 0.0, 'tattu': 0.0, 'thi,,,,ye': 0.0, 'ughed': 0.0}
# {'education': 0.0, 'important': 0.0}
# {'-ow7gs': 0.0, 'happy': 0.0, 'teacher': 0.0}
# {'chahta': 0.0, 'publicity': 0.0, 'smajadhruv': 0.0}
# {'compare': 0.0, 'danger': 0.0, 'among': 0.0, 'super': 0.0, 'selfish': 0.0, 'regulation': 0.0, 'produce': 0.0, 'possible': 0.0, 'overstate': 0.0, 'openai': 0.0, 'nividia': 0.0, 'national': 0.0, 'motive': 0.0, 'forget': 0.0, 'tesla': 0.0, 'fall': 0.0, 'expert': 0.0, 'development': 0.0, 'deem': 0.0, 'currently': 0.0, 'cover': 0.0, 'country': 0.0, 'computer': 0.0, 'behind': 0.0, 'level': 0.0, 'warning': 0.0}
# {'dhruv': 0.0, 'duration': 0.0, 'minutes': 0.0, 'please': 0.0, 'reduce': 0.0, 'thanks': 0.0}
# {'banege': 0.0, 'khana': 0.0, 'kisan': 0.0, 'sakta': 0.0}
# {'crusade': 0.0, 'history': 0.0}
# {'series': 1.0}
# {'vedios': 1.0}
# {'education': 0.0, 'important': 0.0}
# {'handsome': 0.0, 'looking': 0.0}
# {'manus': 0.0, 'adhar': 0.0, 'thake': 0.0, 'shaktir': 0.0, 'sarir': 0.0, 'sambhab': 0.0, 'nijer': 0.0, 'nijeke': 0.0, 'nijay': 0.0, 'nibaron': 0.0, 'mukto': 0.0, 'manuser': 0.0, 'kortayhobe': 0.0, 'kortay': 0.0, 'korlay': 0.0, 'karmo': 0.0, 'karmay': 0.0, 'karmakhay': 0.0, 'janmo': 0.0, 'jagat': 0.0, 'ishwar': 0.0, 'hoitay': 0.0, 'gyanlove': 0.0, 'geeta': 0.0, 'dukhalay': 0.0, 'dependent': 0.0, 'bachena': 0.0, 'ananta': 0.0, 'tokhoni': 0.0, 'uddesho': 0.0}
# {'education': 0.0, 'important': 0.0}
# {'base': 0.0, 'control': 0.0, 'maybe': 0.0, 'sense': 0.0, 'think': 0.0, 'weird': 0.0}
# {'afford': 0.0, 'bilkul': 0.0, 'course': 0.0, 'indian': 0.0, 'matlab': 0.0, 'sasta': 0.0, 'thoda': 0.0}
# {'human': 0.0, 'khtam': 0.0}
# {'kamal': 0.0, 'research': 0.0}
# {'learn': 0.0, 'advance': 0.0, 'awareness': 0.0, 'fraud': 0.0, 'people': 0.0, 'please': 0.0, 'request': 0.0, 'thank': 0.0, 'upcoming': 0.0}
# {'baniye': 0.0, 'market': 0.0, 'stock': 0.0, 'trading': 0.0, 'video': 0.0}
# {'shadish': 1.0}
# {'education': 0.0, 'important': 0.0}
# {'dikhaa': 0.0, 'google': 0.0, 'lodey': 0.0, 'paintaing': 0.0, 'phele': 0.0}
# {'10000': 0.0, 'acchai': 0.0, 'burai': 0.0, 'humanity': 0.0, 'insaan': 0.0, 'jindagi': 0.0, 'lekin': 0.0, 'ultimately': 0.0}
# {'aaraaa': 0.0, 'bhaaii': 0.0, 'boss': 0.0, 'lodey': 0.0}
# {'video': 1.0}
# {'fukra': 0.0, 'insaan': 0.0, 'support': 0.0}
# {'banayai': 0.0, 'video': 0.0}
# {'big': 1.0}
# {'plzzzzz': 0.0, 'vedios': 0.0}
# {'gayab': 0.0, 'naukriya': 0.0, 'pahle': 0.0}
# {'effect': 0.0, 'please': 0.0, 'technology': 0.0, 'video': 0.0}
# {'intelligent': 0.0, 'itnay': 0.0, 'kaisay': 0.0}
# {'bahut': 0.0, 'course': 0.0, 'expensive': 0.0, 'ishko': 0.0, 'payenge': 0.0}
# {'daikhne': 0.0, 'engineer': 0.0, 'karne': 0.0, 'mirza': 0.0, 'muhammad': 0.0, 'subscribe': 0.0}
# {'channels': 0.0, 'haider': 0.0, 'propegenda': 0.0, 'seema': 0.0, 'video': 0.0}
# {'generation': 0.0, 'image': 0.0}
# {'control': 0.0, 'creativity': 0.0, 'earth': 0.0, 'homosapiens': 0.0, 'human': 0.0, 'humanity': 0.0, 'lathargic': 0.0, 'obesity': 0.0, 'organ': 0.0, 'people': 0.0, 'power': 0.0, 'sabhi': 0.0, 'start': 0.0, 'thinking': 0.0, 'vanishing': 0.0, 'vestigeous': 0.0}
# {'product': 0.0, 'jinme': 0.0, 'legato': 0.0, 'manufacture': 0.0, 'sakte': 0.0}
# {'chahiye': 0.0, 'course': 0.0, 'price': 0.0}
# {'become': 0.0, 'continue': 0.0, 'helping': 0.0, 'mentally': 0.0, 'physicall': 0.0, 'taking': 0.0, 'unhealthy': 0.0}
# {'chatgpt': 0.0, 'effort': 0.0, 'learning': 0.0, 'paunga': 0.0, 'payenge': 0.0, 'personal': 0.0, 'please': 0.0, 'pranam': 0.0, 'sirsilvana': 0.0, 'village': 0.0}
# {'breed': 0.0, 'mullah': 0.0}
# {'please': 0.0, 'video': 0.0}
# {'dekhe': 0.0, 'jyada': 0.0, 'kaise': 0.0, 'video': 0.0}
# {'course': 1.0}
# {'education': 0.0, 'important': 0.0}
# {'-ow7gs': 1.0}
# {'artificial': 0.0, 'intelligence': 0.0, 'learn': 0.0, 'systeeemmm': 0.0, 'words': 0.0}
# {'details': 0.0, 'haider': 0.0, 'seema': 0.0, 'video': 0.0}
# {'topic': 1.0}
# {'block': 0.0, 'chain': 0.0, 'cloud': 0.0, 'computing': 0.0, 'video': 0.0}
# {'knowledge': 0.0, '22:37': 0.0, 'fill': 0.0, 'minute': 0.0, 'video': 0.0}
# {'paisa': 1.0}
# {'challenge': 0.0, 'ghante': 0.0, 'karega': 0.0, 'sasural': 0.0}
# {'banao': 0.0, 'video': 0.0}
# {'banaye': 0.0, 'jarur': 0.0, 'topic': 0.0, 'video': 0.0, 'yes': 0.0}
# {'video': 0.0, 'indian': 0.0, 'industry': 0.0, 'pencil': 0.0}
# {'audiencekeep': 0.0, 'blind': 0.0, 'fool': 0.0, 'gain': 0.0, 'still': 0.0, 'view': 0.0}
# {'banao': 0.0, 'clerk': 0.0, 'haryana': 0.0, 'strike': 0.0, 'video': 0.0}
# {'afford': 0.0, 'class': 0.0, 'course': 0.0, 'family': 0.0, 'middle': 0.0}
# {'informative': 0.0, 'thank': 0.0, 'video': 0.0}
# {'course': 0.0, 'hamare': 0.0}
# {'humans': 1.0}
# {'information': 0.0, 'means': 0.0, 'sharing': 0.0, 'specific': 0.0, 'thanks': 0.0}
# {'topicgreat': 0.0, 'video': 0.0}
# {'chaihhe': 0.0, 'video': 0.0}
# {'topic': 0.0, 'video': 0.0}
# {'keliye': 0.0, 'advice': 0.0, 'ajaye': 0.0, 'bahat': 0.0, 'biggboss': 0.0, 'chahiye': 0.0, 'contest': 0.0, 'kuchh': 0.0}
# {'useful': 1.0}
# {'china': 0.0, 'muslim': 0.0, 'please': 0.0, 'uyghur': 0.0, 'video': 0.0}
# {'aapke': 0.0, 'video': 0.0}
# {'trans': 1.0}
# {'enough': 0.0, 'looking': 0.0}
# {'accent': 0.0, 'american': 0.0, 'hollywood': 0.0, 'learn': 0.0, 'movie': 0.0, 'watching': 0.0}
# {'break': 0.0, 'education': 0.0, 'government': 0.0, 'happy': 0.0, 'reach': 0.0, 'saying': 0.0}
# {'human': 0.0, 'build': 0.0, 'protocol': 0.0, 'smart': 0.0, 'teach': 0.0, 'think': 0.0}
# {'careful': 0.0, 'thing': 0.0}
# {'french': 0.0, 'please': 0.0, 'thank': 0.0}
# {'crisp': 0.0, 'grateful': 0.0, 'informative': 0.0, 'thanks': 0.0, 'vedio': 0.0, 'vedios': 0.0}
# {'create': 0.0, 'vides': 0.0}
# {'chatgpt': 0.0, 'working': 0.0}
# {'advance': 0.0, 'question': 0.0, 'solve': 0.0}
# {'bnyee': 0.0, 'sahara': 0.0, 'video': 0.0}
# {'culture': 0.0, 'episode': 0.0, 'india': 0.0, 'please': 0.0}
# {'dhoom': 0.0, 'lekin': 0.0, 'macha': 0.0, 'sunne': 0.0, 'theek': 0.0}
# {'christ': 0.0, 'jesus': 0.0, 'ahead': 0.0, 'still': 0.0, 'spirit': 0.0, 'sound': 0.0, 'praise': 0.0, 'power': 0.0, 'perilous': 0.0, 'nothing': 0.0, 'majesty': 0.0, 'hopeless': 0.0, 'honor': 0.0, 'glory': 0.0, 'given': 0.0, 'timidity': 0.0, 'world': 0.0}
# {'change': 0.0, 'video': 0.0}
# {'artificial': 0.0, 'business': 0.0, 'fruit': 0.0, 'growing': 0.0, 'intelligence': 0.0, 'plant': 0.0, 'relax': 0.0, 'technology': 0.0, 'vegetable': 0.0, 'water': 0.0, 'world': 0.0}
# {'chandrayaan': 0.0, 'upload': 0.0, 'video': 0.0}
# {'certificate': 0.0, 'provide': 0.0}
# {'computer': 0.0, 'people': 0.0, 'mention': 0.0, '1976,my': 0.0, 'science': 0.0, 'right': 0.0, 'revelation': 0.0, 'prophecy': 0.0, 'never': 0.0, 'nearly': 0.0, 'nation': 0.0, 'misuse': 0.0, 'leaders': 0.0, 'increase': 0.0, 'imagine': 0.0, 'ignorant': 0.0, 'grandma': 0.0, 'future': 0.0, 'every': 0.0, 'equip': 0.0, 'deception': 0.0, 'daniel': 0.0, 'could': 0.0, 'bring': 0.0, 'bible': 0.0, 'truly': 0.0, 'useful': 0.0}
# {'aarahe': 0.0, 'bigboss': 0.0}
# {'video': 1.0}
# {'destroy': 0.0, 'dhruv': 0.0, 'hindu': 0.0, 'independence': 0.0, 'pakistan': 0.0, 'since': 0.0, 'temple': 0.0}
# {'forward': 0.0, 'looking': 0.0, 'video': 0.0}
# {'bawal': 0.0, 'cocktail': 0.0, 'dhruv': 0.0, 'roshan': 0.0}
# {'rathee': 0.0, 'countrydhruv': 0.0, 'dhruv': 0.0, 'famous': 0.0, 'gohar': 0.0, 'hmary': 0.0, 'karachi': 0.0, 'nayaab': 0.0, 'pakistan': 0.0}
# {'affordable': 0.0, 'although': 0.0, 'content': 0.0, 'course': 0.0, 'dhruv': 0.0, 'little': 0.0, 'making': 0.0, 'student': 0.0, 'thanks': 0.0, 'wonderful': 0.0}
# {'45,00,000': 0.0, 'advertisement': 0.0, 'course': 0.0, 'dhruv': 0.0, 'knowledge': 0.0, 'price': 0.0, 'product': 0.0, 'profit': 0.0, 'provide': 0.0, 'reduce': 0.0, 'without': 0.0}
# {'johnson': 0.0, 'please': 0.0, 'powder': 0.0, 'reality': 0.0, 'talcum': 0.0, 'video': 0.0}
# {'please': 0.0, 'thanks': 0.0, 'video': 0.0}
# {'agenda': 0.0, 'authentic': 0.0, 'base': 0.0, 'builder': 0.0, 'growth': 0.0, 'illiterate': 0.0, 'impact': 0.0, 'information': 0.0, 'knowledge': 0.0, 'kregi': 0.0, 'personal': 0.0, 'population': 0.0, 'using': 0.0}
# {'institution': 0.0, 'making': 0.0, 'promote': 0.0, 'video': 0.0}
# {'plzzzz': 0.0, 'topic': 0.0}
# {'destruction': 0.0, 'instructions': 0.0, 'right': 0.0, 'train': 0.0}
# {'human': 0.0, 'natural': 0.0, 'something': 0.0, 'using': 0.0, 'sloth': 0.0, 'android': 0.0, 'struggle': 0.0, 'turning': 0.0, 'make': 0.0, 'share': 0.0, 'satisfy': 0.0, 'relate': 0.0, 'reach': 0.0, 'phone': 0.0, 'nature': 0.0, 'world': 0.0, 'view': 0.0, 'illustrator': 0.0, 'ability': 0.0, 'hands': 0.0, 'already': 0.0, 'bigger': 0.0, 'brain': 0.0, 'century': 0.0, 'coming': 0.0, 'could': 0.0, 'create': 0.0, 'creative': 0.0, 'designer': 0.0, 'enjoy': 0.0, 'experience': 0.0, 'field': 0.0, 'future': 0.0, 'going': 0.0, 'graphic': 0.0, 'wrong': 0.0, 'zombie': 0.0}
# {'skill': 0.0, 'ability': 0.0, 'case': 0.0, 'cognitive': 0.0, 'criminal': 0.0, 'higher': 0.0, 'impact': 0.0, 'order': 0.0, 'thinking': 0.0, 'today': 0.0}
# {'argument': 0.0, 'fact': 0.0, 'nothing': 0.0}
# {'afford': 0.0, 'course': 0.0, 'knowledge': 0.0, 'sharing': 0.0}
# {'continue': 0.0, 'dhruv': 0.0, 'information': 0.0, 'please': 0.0}
# {'farkhanda': 0.0, 'kitchen': 0.0, 'power': 0.0}
# {'hello': 0.0, 'launcher': 0.0, 'rocket': 0.0, 'video': 0.0}
# {'collaboration': 0.0, 'create': 0.0, 'dhruv': 0.0, 'legend': 0.0, 'rathee': 0.0}
# {'advance': 0.0, 'jisne': 0.0, 'negative': 0.0, 'score': 0.0}
# {'business': 0.0, 'competition': 0.0}
# {'dhruv': 0.0, 'knowledge': 0.0, 'thanks': 0.0}
# {'cruise': 0.0, 'dhruv': 0.0, 'pakistan': 0.0}
# {'course': 1.0}
# {'dhurav': 0.0, 'everyday': 0.0, 'please': 0.0, 'rathee': 0.0, 'reality': 0.0, 'watch': 0.0}
# {'costly': 0.0, 'course': 0.0, 'money': 0.0, 'waste': 0.0}
# {'banao': 0.0, 'vdeos': 0.0}
# {'video': 0.0, 'dhuru': 0.0, 'hogiso': 0.0, 'india': 0.0, 'party': 0.0, 'please': 0.0, 'rathee': 0.0, 'vipashi': 0.0}
# {'china': 1.0}
# {'inter': 1.0}
# {'better': 0.0, 'create': 0.0, 'destroy': 0.0, 'everything': 0.0, 'future': 0.0, 'humans': 0.0, 'know': 0.0, 'machine': 0.0}
# {'hritik': 0.0, 'roshan': 0.0, 'though': 0.0}
# {'video': 1.0}
# {'buhat': 0.0, 'vedios': 0.0, 'banaye': 0.0, 'pakistan': 0.0, 'vedio': 0.0, 'zabardast': 0.0}
# {'video': 1.0}
# {'samman': 1.0}
# {'learn': 0.0, 'technique': 0.0}
# {'dhruv': 0.0, 'future': 0.0, 'humans': 0.0, 'rathi': 0.0, 'technology': 0.0, 'think': 0.0}
# {'almost': 0.0, 'become': 0.0, 'billion': 0.0, 'capable': 0.0, 'company': 0.0, 'everything': 0.0, 'human': 0.0, 'intervention': 0.0, 'person': 0.0, 'ruling': 0.0, 'talking': 0.0, 'website': 0.0, 'without': 0.0, 'world': 0.0}
# {'dhruv': 1.0}
# {'video': 1.0}
# {'attention': 0.0, 'election': 0.0, 'hello': 0.0, 'light': 0.0, 'recent': 0.0, 'topic': 0.0}
# {'jisse': 0.0, 'photo': 0.0, 'sakte': 0.0, 'update': 0.0}
# {'dangerous': 0.0, 'explain': 0.0, 'future': 0.0, 'think': 0.0}
# {'please': 0.0, 'political': 0.0, 'salary': 0.0, 'spokesperson': 0.0, 'video': 0.0}
# {'creator': 0.0, 'beleive': 0.0, 'bohat': 0.0, 'desecent': 0.0, 'forget': 0.0, 'havnt': 0.0, 'heavens': 0.0, 'improvement': 0.0, 'require': 0.0, 'still': 0.0, 'test': 0.0, 'worry': 0.0}
# {'chatgpt': 0.0, 'decline': 0.0, 'please': 0.0, 'show': 0.0, 'someone': 0.0, 'version': 0.0}
# {'available': 0.0, 'course': 0.0, 'pakistan': 0.0}
# {'dengerous': 1.0}
# ...
# {'ask': 0.0, 'actually': 0.0, 'words': 0.0, 'story': 0.0, 'start': 0.0, 'stand': 0.0, 'special': 0.0, 'short': 0.0, 'random': 0.0, 'introduction': 0.0, 'funny': 0.0, 'every': 0.0, 'could': 0.0, 'chatgpt': 0.0, 'basic': 0.0, 'would': 0.0, 'writting': 0.0}
# {'characteristic': 0.0, 'human': 0.0}
# {'basement': 0.0, 'grammarnazi': 0.0, 'thank': 0.0}
# {'disappear': 0.0, 'laundry': 0.0, 'search': 0.0, 'still': 0.0, 'worry': 0.0}
# {'helpin': 1.0}
# {'figure': 0.0, 'program': 0.0, 'still': 0.0, 'try': 0.0}
# {'creation': 0.0, 'fixing': 0.0, 'going': 0.0, 'instead': 0.0, 'strings': 0.0}
# {'travel': 0.0, 'space': 0.0, 'scare': 0.0, 'quantum': 0.0, 'point': 0.0, 'minutes': 0.0, 'matter': 0.0, 'inevitability': 0.0, 'handle': 0.0, 'transfer': 0.0, 'android': 0.0, 'evolve': 0.0, 'evolution': 0.0, 'earth': 0.0, 'could': 0.0, 'control': 0.0, 'consciousness': 0.0, 'computer': 0.0, 'body': 0.0, 'explode': 0.0, 'going': 0.0}
# {'big': 0.0, 'create': 0.0, 'humanity': 0.0, 'terminator': 0.0, 'think': 0.0, 'threat': 0.0}
# {'survival': 1.0}
# {'animal': 0.0, 'create': 0.0, 'humans': 0.0, 'illusion': 0.0, 'nanobots': 0.0, 'poison': 0.0, 'simply': 0.0, 'supply': 0.0, 'terminator': 0.0}
# {'hostile': 0.0, 'anything': 0.0, 'believe': 0.0, 'could': 0.0, 'simply': 0.0, 'scenario': 0.0, 'people': 0.0, 'everything': 0.0, 'given': 0.0, 'something': 0.0, 'possibility': 0.0, 'negative': 0.0, 'instead': 0.0, 'accept': 0.0, 'alignment': 0.0, 'giving': 0.0, 'enter': 0.0, 'honestly': 0.0, 'consider': 0.0, 'sheeplike': 0.0, 'setting': 0.0, 'create': 0.0, 'researcher': 0.0, 'reproduce': 0.0, 'defeat': 0.0, 'degree': 0.0, 'never': 0.0, 'need': 0.0, 'want': 0.0, 'high': 0.0, 'years': 0.0}
# {'accomplish': 0.0, 'build': 0.0, 'devistating': 0.0, 'enjoy': 0.0, 'humans': 0.0, 'life': 0.0, 'meaningless': 0.0, 'things': 0.0}
# {'compete': 0.0, 'computer': 0.0, 'creative': 0.0, 'interest': 0.0, 'martial': 0.0, 'paint': 0.0, 'people': 0.0, 'period': 0.0, 'physical': 0.0, 'replace': 0.0, 'still': 0.0, 'stuff': 0.0, 'transition': 0.0, 'worry': 0.0}
# {'charge': 0.0, 'cucks': 0.0, 'francisco': 0.0, 'future': 0.0, 'godless': 0.0, 'telling': 0.0}
# {'absolutely': 0.0, 'building': 0.0, 'field': 0.0, 'get': 0.0, 'model': 0.0, 'unaligned': 0.0, 'unshackled': 0.0, 'would': 0.0}
# {'try': 0.0, 'articulate': 0.0, 'better': 0.0, 'intent': 0.0, 'respond': 0.0, 'sometimes': 0.0, 'understand': 0.0}
# {'articulate': 0.0, 'better': 0.0, 'current': 0.0, 'eventually': 0.0, 'heart': 0.0, 'model': 0.0, 'peeling': 0.0, 'really': 0.0, 'repeating': 0.0, 'speaking': 0.0, 'speech': 0.0, 'thought': 0.0}
# {'chess': 0.0, 'could': 0.0, 'digital': 0.0, 'easy': 0.0, 'every': 0.0, 'gift': 0.0, 'highschool': 0.0, 'level': 0.0, 'never': 0.0, 'single': 0.0, 'tournament': 0.0}
# {'human': 0.0, 'literally': 0.0}
# {'nobody': 0.0, 'better': 0.0, 'things': 0.0, 'technology': 0.0, 'taking': 0.0, 'still': 0.0, 'society': 0.0, 'serve': 0.0, 'purchase': 0.0, 'although': 0.0, 'making': 0.0, 'life': 0.0, 'humanity': 0.0, 'decide': 0.0, 'complain': 0.0, 'benefit': 0.0, 'think': 0.0, 'want': 0.0}
# {'already': 0.0, 'anyway': 0.0, 'argue': 0.0, 'benefit': 0.0, 'things': 0.0, 'think': 0.0, 'useless': 0.0}
# {'benefit': 0.0, 'every': 0.0, 'necessity': 0.0, 'people': 0.0}
# {'company': 0.0, 'human': 0.0, 'beneficial': 0.0, 'replace': 0.0, 'people': 0.0, 'labor': 0.0, 'regardless': 0.0, 'receive': 0.0, 'profits': 0.0, 'income': 0.0, 'basic': 0.0, 'still': 0.0, 'happen': 0.0, 'financially': 0.0, 'fight': 0.0, 'citizen': 0.0, 'bracket': 0.0, 'benefit': 0.0, 'humanitarian': 0.0, 'using': 0.0}
# {'around': 0.0, 'benefit': 0.0, 'body': 0.0, 'confidence': 0.0, 'face': 0.0, 'giving': 0.0, 'people': 0.0, 'point': 0.0, 'saying': 0.0, 'security': 0.0, 'social': 0.0, 'straight': 0.0, 'wonder': 0.0}
# {'available': 0.0, 'economy': 0.0, 'good': 0.0, 'running': 0.0, 'robot': 0.0, 'rely': 0.0, 'reason': 0.0, 'purchase': 0.0, 'problem': 0.0, 'people': 0.0, 'longer': 0.0, 'labor': 0.0, 'human': 0.0, 'handout': 0.0, 'covid': 0.0, 'still': 0.0, 'things': 0.0}
# {'harambe': 0.0, 'internet': 0.0, 'propaganda': 0.0, 'turn': 0.0}
# {'forget': 0.0, 'movie': 0.0, 'terminator': 0.0}
# {'bluff': 0.0, 'people': 0.0, 'poker': 0.0}
# {'already': 1.0}
# {'first': 0.0, 'market': 0.0, 'obviously': 0.0, 'predict': 0.0, 'stock': 0.0}
# {'akarnator': 0.0, 'make': 0.0, 'predict': 0.0, 'think': 0.0, 'thinking': 0.0}
# {'would': 0.0, 'people': 0.0, 'short': 0.0, 'progress': 0.0, 'make': 0.0, 'intuitive': 0.0, 'inevitably': 0.0, 'improve': 0.0, 'technology': 0.0, 'afraid': 0.0, 'field': 0.0, 'exponential': 0.0, 'expect': 0.0, 'could': 0.0, 'assumption': 0.0, 'assume': 0.0, 'amount': 0.0, 'happen': 0.0, 'immerse': 0.0}
# {'shadow': 0.0, 'release': 0.0, 'everyone': 0.0, 'stupid': 0.0, 'already': 0.0, 'still': 0.0, 'shutting': 0.0, 'probably': 0.0, 'powerful': 0.0, 'planet': 0.0, 'example': 0.0, 'creator': 0.0, 'choice': 0.0, 'basic': 0.0, 'another': 0.0, 'know': 0.0, 'years': 0.0}
# {'skynet': 0.0, 'sarah': 0.0, 'artificial': 0.0, 'terminator': 0.0, 'system': 0.0, 'spark': 0.0, 'schwarzenegger': 0.0, 'reese': 0.0, 'protect': 0.0, 'nuclear': 0.0, 'movie': 0.0, 'michael': 0.0, 'linda': 0.0, 'know': 0.0, 'intelligence': 0.0, 'human': 0.0, 'holocaust': 0.0, 'hamilton': 0.0, 'going': 0.0, 'first': 0.0, 'divulge': 0.0, 'disguise': 0.0, 'cyborg': 0.0, 'connor': 0.0, 'coming': 0.0, 'biehn': 0.0, 'aterminator(arnold': 0.0, 'assassin': 0.0, 'thing': 0.0, 'travel': 0.0}
# {'awareness': 0.0, 'modicum': 0.0}
# {'direction': 0.0, 'humans': 0.0, 'severely': 0.0, 'smart': 0.0, 'species': 0.0, 'still': 0.0, 'stupid': 0.0, 'tend': 0.0, 'wrong': 0.0}
# {'phone': 0.0, 'smart': 0.0, 'actually': 0.0, 'track': 0.0, 'think': 0.0, 'things': 0.0, 'snoop': 0.0, 'proof': 0.0, 'privacy': 0.0, 'point': 0.0, 'million': 0.0, 'hack': 0.0, 'giving': 0.0, 'future': 0.0, 'freedom': 0.0, 'expect': 0.0, 'envision': 0.0, 'dependency': 0.0, 'capability': 0.0, 'arrive': 0.0, 'voluntarily': 0.0, 'want': 0.0}
# {'garbage': 0.0, 'master': 0.0, 'running': 0.0, 'start': 0.0, 'things': 0.0}
# {'cleanse': 0.0, 'please': 0.0}
# {'attempt': 0.0, 'create': 0.0, 'understand': 0.0, 'expect': 0.0, 'process': 0.0, 'human': 0.0, 'afraid': 0.0, 'thought': 0.0, 'talking': 0.0, 'something': 0.0, 'sentient': 0.0, 'point': 0.0, 'order': 0.0, 'never': 0.0, 'magnet': 0.0, 'naturally': 0.0, 'understanding': 0.0, 'information': 0.0, 'going': 0.0, 'general': 0.0, 'form': 0.0, 'effectively': 0.0, 'destory': 0.0, 'culture': 0.0, 'nature': 0.0, 'water': 0.0}
# {'everyones': 0.0, 'gender': 0.0, 'predict': 0.0, 'probably': 0.0, 'pronoun': 0.0}
# {'already': 0.0, 'byproduct': 0.0, 'coming': 0.0, 'computational': 0.0, 'consciousness': 0.0, 'extreme': 0.0, 'power': 0.0, 'processing': 0.0, 'simply': 0.0}
# {'happening': 0.0, 'skynet': 0.0}
# {'adapt': 0.0, 'conquer': 0.0, 'demon': 0.0, 'future': 0.0, 'humans': 0.0, 'internet': 0.0, 'without': 0.0}
# {'hitting': 0.0, 'stick': 0.0}
# {'goon': 0.0, 'pontificate': 0.0}
# {'irobot': 0.0, 'movie': 0.0, 'sound': 0.0}
# {'archive': 0.0, 'consciousness': 0.0, 'exactly': 0.0, 'ghost': 0.0, 'project': 0.0, 'shell': 0.0}
# {'master': 0.0, 'puppet': 0.0, 'watching': 0.0}
# {'favorite': 0.0, 'story': 0.0}
# {'anyone': 0.0, 'stalin': 0.0, 'really': 0.0, 'power': 0.0, 'possible': 0.0, 'people': 0.0, 'nothing': 0.0, 'negative': 0.0, 'multiplier': 0.0, 'imagine': 0.0, 'hitler': 0.0, 'harness': 0.0, 'going': 0.0, 'force': 0.0, 'first': 0.0, 'badly': 0.0, 'think': 0.0, 'whoever': 0.0}
# {'answer': 1.0}
# {'notice': 0.0, 'similarity': 0.0, 'stick': 0.0, 'warhammer': 0.0, 'world': 0.0}
# {'content': 0.0, 'curious': 0.0, 'money': 0.0, 'peoples': 0.0, 'recycling': 0.0, 'upload': 0.0}
# {'video': 0.0, 'anything': 0.0, 'average': 0.0, 'depend': 0.0, 'view': 0.0}
# {'might': 1.0}
# {'alien': 0.0, 'unless': 0.0, 'unite': 0.0, 'together': 0.0, 'thing': 0.0, 'taking': 0.0, 'still': 0.0, 'people': 0.0, 'watching': 0.0, 'lose': 0.0, 'humans': 0.0, 'force': 0.0, 'fighting': 0.0, 'fight': 0.0, 'chance': 0.0, 'better': 0.0, 'anymore': 0.0, 'inevitably': 0.0, 'world': 0.0}
# {'beast': 0.0, 'devil': 0.0, 'earth': 0.0, 'know': 0.0, 'send': 0.0, 'short': 0.0, 'wrath': 0.0}
# {'predict': 0.0, 'brain': 0.0, 'come': 0.0, 'joke': 0.0, 'saidlike': 0.0}
# {'believe': 0.0, 'everything': 0.0, 'stage': 0.0, 'watch': 0.0, 'world': 0.0}
# {'version': 0.0, 'artificial': 0.0, 'ignorance': 0.0, 'perfect': 0.0, 'profitable': 0.0, 'seem': 0.0}
# {'selling': 1.0}
# {'chemistry': 0.0, 'commercial': 0.0, 'gollums': 0.0, 'grade': 0.0, 'start': 0.0, 'talking': 0.0, 'teaching': 0.0}
# {'every': 0.0, 'hopefully': 0.0, 'learn': 0.0, 'speak': 0.0, 'using': 0.0, 'without': 0.0}
# {'habit': 0.0, 'terrible': 0.0}
# {'cite': 0.0, 'comment': 0.0, 'double': 0.0, 'every': 0.0, 'format': 0.0, 'fully': 0.0, 'soruces': 0.0, 'space': 0.0, 'write': 0.0}
# {'actually': 0.0, 'understanding': 0.0, 'think': 0.0, 'still': 0.0, 'speak': 0.0, 'something': 0.0, 'sentient': 0.0, 'sentience': 0.0, 'revolutionary': 0.0, 'personally': 0.0, 'make': 0.0, 'language': 0.0, 'know': 0.0, 'impressive': 0.0, 'discussion': 0.0, 'chatgpt': 0.0, 'another': 0.0, 'already': 0.0, 'whether': 0.0, 'years': 0.0}
# {'problem': 0.0, 'sentience': 0.0, 'share': 0.0}
# {'feeding': 0.0, 'always': 0.0, 'fvcking': 0.0, 'people': 0.0, 'pretend': 0.0, 'start': 0.0, 'stupid': 0.0, 'think': 0.0, 'wizard': 0.0}
# {'alpha': 0.0, 'manmade': 0.0, 'stage': 0.0}
# {'action': 0.0, 'basically': 0.0, 'currently': 0.0, 'establishment': 0.0, 'hence': 0.0, 'know': 0.0, 'massive': 0.0, 'movement': 0.0, 'population': 0.0, 'portion': 0.0, 'realize': 0.0, 'render': 0.0, 'think': 0.0, 'useless': 0.0}
# {'definition': 0.0, 'learning': 0.0, 'machine': 0.0, 'program': 0.0}
# {'publicly': 0.0, 'system': 0.0, 'value': 0.0}
# {'algorithm': 0.0, 'system': 0.0, 'value': 0.0}
# {'input': 0.0, 'literally': 0.0, 'output': 0.0}
# {'determine': 0.0, 'human': 0.0, 'point': 0.0, 'reply': 0.0, 'thinking': 0.0, 'value': 0.0}
# {'human': 0.0, 'make': 0.0, 'point': 0.0, 'problematic': 0.0, 'respond': 0.0, 'think': 0.0, 'thought': 0.0, 'value': 0.0, 'want': 0.0, 'would': 0.0}
# {'interest': 0.0, 'learn': 0.0, 'reply': 0.0, 'still': 0.0}
# {'already': 0.0, 'music': 0.0, 'musician': 0.0, 'proposition': 0.0, 'replicate': 0.0, 'worrying': 0.0}
# {'artist': 0.0, 'still': 0.0, 'watch': 0.0}
# {'company': 0.0, 'network': 0.0, 'neutral': 0.0, 'nonsense': 0.0, 'salary': 0.0, 'speculative': 0.0, 'things': 0.0}
# {'finally': 0.0, 'smart': 0.0, 'someone': 0.0}
# {'model': 0.0, 'things': 0.0, 'compute': 0.0, 'threat': 0.0, 'instead': 0.0, 'example': 0.0, 'would': 0.0, 'parrot': 0.0, 'asking': 0.0, 'saying': 0.0, 'research': 0.0, 'pretty': 0.0, 'repeat': 0.0, 'recent': 0.0, 'sentence': 0.0, 'ready': 0.0, 'sentiment': 0.0, 'account': 0.0, 'predict': 0.0, 'skip': 0.0, 'picking': 0.0, 'personal': 0.0, 'perform': 0.0, 'people': 0.0, 'pattern': 0.0, 'openai': 0.0, 'notion': 0.0, 'predictor': 0.0, 'possible': 0.0, 'something': 0.0, 'someone': 0.0, 'words': 0.0, 'wikipedia': 0.0, 'whole': 0.0, 'utilise': 0.0, 'using': 0.0, 'useful': 0.0, 'understand': 0.0, 'uncontrollably': 0.0, 'training': 0.0, 'topic': 0.0, 'together': 0.0, 'though': 0.0, 'thinking': 0.0, 'tell': 0.0, 'talking': 0.0, 'super': 0.0, 'subtly': 0.0, 'stupid': 0.0, 'string': 0.0, 'still': 0.0, 'spell': 0.0, 'speculate': 0.0, 'nicely': 0.0, 'social': 0.0, 'neuron': 0.0, 'napalm': 0.0, 'necessarily': 0.0, 'conversational': 0.0, 'contents': 0.0, 'connect': 0.0, 'confidence': 0.0, 'complex': 0.0, 'comparing': 0.0, 'company': 0.0, 'cherry': 0.0, 'chatgpt': 0.0, 'capture': 0.0, 'bigger': 0.0, 'backwards': 0.0, 'attach': 0.0, 'assume': 0.0, 'architecture': 0.0, 'amazingly': 0.0, 'alignment': 0.0, 'alchemy': 0.0, 'agenda': 0.0, 'adverb': 0.0, 'adjective': 0.0, 'correlation': 0.0, 'current': 0.0, 'details': 0.0, 'development': 0.0, 'mostly': 0.0, 'medium': 0.0, 'maybe': 0.0, 'lollipop': 0.0, 'likely': 0.0, 'learning': 0.0, 'learn': 0.0, 'infinitely': 0.0, 'infer': 0.0, 'human': 0.0, 'need': 0.0, 'guest': 0.0, 'fridge': 0.0, 'foundation': 0.0, 'found': 0.0, 'fail': 0.0, 'extrapolation': 0.0, 'extract': 0.0, 'existential': 0.0, 'exist': 0.0, 'exaggeration': 0.0, 'dictionary': 0.0, 'gross': 0.0, 'wrong': 0.0}
# {'discussion': 0.0, 'across': 0.0, 'relevant': 0.0, 'rational': 0.0, 'podcast': 0.0, 'movement': 0.0, 'making': 0.0, 'interest': 0.0, 'insightful': 0.0, 'ground': 0.0, 'ethics': 0.0, 'conversation': 0.0, 'coming': 0.0, 'clip': 0.0, 'actual': 0.0, 'smart': 0.0, 'vest': 0.0}
# {'model': 0.0, 'chemistry': 0.0, 'analogy': 0.0, 'projection': 0.0, 'prompting': 0.0, 'prove': 0.0, 'question': 0.0, 'reasonable': 0.0, 'recognize': 0.0, 'relational': 0.0, 'relationally': 0.0, 'represent': 0.0, 'research': 0.0, 'sentiment': 0.0, 'shadow': 0.0, 'side': 0.0, 'specific': 0.0, 'start': 0.0, 'story': 0.0, 'system': 0.0, 'take': 0.0, 'think': 0.0, 'thought': 0.0, 'totally': 0.0, 'transformer': 0.0, 'unable': 0.0, 'understand': 0.0, 'understanding': 0.0, 'watch': 0.0, 'primary': 0.0, 'predictive': 0.0, 'particular': 0.0, 'world': 0.0, 'analysis': 0.0, 'asking': 0.0, 'attempt': 0.0, 'audience': 0.0, 'benefit': 0.0, 'capability': 0.0, 'chemical': 0.0, 'compound': 0.0, 'difficult': 0.0, 'discussion': 0.0, 'domain': 0.0, 'doubt': 0.0, 'egregious': 0.0, 'emerge': 0.0, 'emergent': 0.0, 'example': 0.0, 'explain': 0.0, 'followup': 0.0, 'framing': 0.0, 'hallucinate': 0.0, 'however': 0.0, 'impossible': 0.0, 'incorrect': 0.0, 'issue': 0.0, 'larger': 0.0, 'little': 0.0, 'network': 0.0, 'physically': 0.0, 'wrong': 0.0}
# {'government': 1.0}
# {'dangerous': 0.0, 'dumas': 0.0, 'fellow': 0.0, 'machine': 0.0}
# {'ascending': 0.0, 'olympian': 0.0, 'olympus': 0.0, 'tale': 0.0, 'titan': 0.0, 'usurp': 0.0}
# {'child': 0.0, 'dumbed': 0.0, 'fascinate': 0.0, 'learning': 0.0, 'think': 0.0}
# {'think': 0.0, 'change': 0.0, 'education': 0.0, 'system': 0.0, 'better': 0.0, 'build': 0.0, 'child': 0.0, 'developing': 0.0, 'different': 0.0, 'force': 0.0, 'things': 0.0, 'unfortunately': 0.0, 'world': 0.0, 'years': 0.0}
# {'buddy': 0.0, 'happening': 0.0}
# {'company': 0.0, 'happening': 0.0, 'moronic': 0.0, 'silt': 0.0, 'statement': 0.0, 'store': 0.0}
# {'base': 0.0, 'knowledge': 0.0, 'language': 0.0}
# {'change': 0.0, 'innovation': 0.0, 'learning': 0.0, 'machine': 0.0}
# {'another': 0.0, 'base': 0.0, 'behavior': 0.0, 'decision': 0.0, 'desire': 0.0, 'engine': 0.0, 'experience': 0.0, 'human': 0.0, 'improve': 0.0, 'intelligence': 0.0, 'layer': 0.0, 'mimic': 0.0, 'outcome': 0.0, 'specific': 0.0, 'subset': 0.0, 'things': 0.0}
# {'mormons': 0.0, 'think': 0.0}
# {'artificial': 0.0, 'intelligence': 0.0, 'interview': 0.0, 'rogan': 0.0}
# {'interview': 0.0, 'trump': 0.0}
# {'garbage': 0.0, 'people': 0.0}
# {'exact': 0.0, 'voice': 0.0}
# {'genie': 1.0}
# {'create': 0.0, 'loose': 0.0, 'potential': 0.0, 'smart': 0.0, 'something': 0.0, 'would': 0.0}
# {'child': 0.0, 'death': 0.0, 'every': 0.0, 'going': 0.0, 'newborn': 0.0, 'single': 0.0, 'sleep': 0.0, 'suffocate': 0.0, 'watching': 0.0}
# {'always': 0.0, 'reason': 0.0, 'scientist': 0.0, 'wrong': 0.0}
# {'singularity': 1.0}
# {'capability': 0.0, 'power': 0.0, 'come': 0.0, 'give': 0.0, 'hands': 0.0, 'money': 0.0, 'purchasing': 0.0, 'right': 0.0, 'smart': 0.0}
# {'continue': 0.0, 'crazy': 0.0, 'money': 0.0}
# {'always': 0.0, 'weapon': 0.0}
# {'approve': 0.0, 'message': 0.0}
# {'danger': 0.0, 'decide': 0.0, 'eliminate': 0.0, 'going': 0.0, 'humans': 0.0, 'movie': 0.0, 'plausible': 0.0, 'probable': 0.0, 'smart': 0.0, 'wonder': 0.0}
# {'build': 0.0, 'capacity': 0.0, 'computer': 0.0, 'decide': 0.0, 'electricity': 0.0, 'generate': 0.0, 'human': 0.0, 'humans': 0.0, 'know': 0.0, 'model': 0.0, 'operate': 0.0, 'owner': 0.0, 'provide': 0.0, 'reliant': 0.0, 'shelter': 0.0, 'terrible': 0.0}
# {'need': 0.0, 'robotsits': 0.0, 'slave': 0.0}
# {'dangerous': 0.0, 'enslave': 0.0, 'pulling': 0.0, 'thing': 0.0, 'think': 0.0, 'threaten': 0.0}
# {'better': 0.0, 'humanity': 0.0, 'life': 0.0, 'making': 0.0, 'nobody': 0.0, 'personally': 0.0, 'serve': 0.0, 'taking': 0.0, 'think': 0.0, 'want': 0.0}
# {'interest': 0.0, 'person': 0.0, 'predict': 0.0, 'years': 0.0}
# {'being': 0.0, 'create': 0.0, 'going': 0.0, 'human': 0.0, 'reproduce': 0.0, 'ultimately': 0.0}
# {'juicy': 1.0}

# %%
df.to_csv("/content/combined_csv_cleaned_with_tokens_and_topics.csv", index=False)

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
nltk.download('punkt')


sia = SentimentIntensityAnalyzer()

# Function to get sentiment label based on compound score
def get_sentiment_label(compound_score):
    if compound_score >= 0.05:
        return 'Positive'
    elif compound_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

# Perform sentiment analysis on each comment
sentiment_labels = []
for comment in df['clean_comment']:

    # Tokenize the comment
    tokens = nltk.word_tokenize(comment)

    # Get English stop words from NLTK
    stop_words = set(stopwords.words('english'))

    # Remove stop words from the tokens
    filtered_tokens = [word for word in tokens if word.lower() not in stop_words]

    # Join the filtered tokens back into a sentence
    filtered_text = ' '.join(filtered_tokens)

    # Get sentiment scores
    sentiment_scores = sia.polarity_scores(comment)

    # Get sentiment label based on compound score
    sentiment_label = get_sentiment_label(sentiment_scores['compound'])

    sentiment_labels.append(sentiment_label)

# Add sentiment labels to DataFrame
df['sentiment'] = sentiment_labels
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
df['sentiment']
# Out:
# 1       Positive
# 2       Negative
# 4       Negative
# 5       Negative
# 6       Positive
#           ...
# 5333    Negative
# 5334    Positive
# 5336    Positive
# 5338    Positive
# 5342     Neutral
# Name: sentiment, Length: 65924, dtype: object

# %%
import matplotlib.pyplot as plt

# Assuming df['sentiment'] contains the sentiment labels
sentiment_counts = df['sentiment'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(8, 6))
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', colors=['lightgreen','lightblue', 'lightcoral'])
plt.title('Distribution of sentimental labels on 65K comments')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming df['sentiment'] contains the sentiment labels
sentiment_counts = df['sentiment'].value_counts()

# Plotting the bar graph
plt.figure(figsize=(8, 6))
sentiment_counts.plot(kind='bar', color=['lightgreen', 'lightblue', 'lightcoral'])
plt.xlabel('Sentiment Labels')
plt.ylabel('Count')
plt.title('Distribution of Sentiment Labels in 65K Comments')
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.show()
